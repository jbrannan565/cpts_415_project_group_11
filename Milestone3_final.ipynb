# %%
from pyspark.sql import SparkSession
from sedona.register import SedonaRegistrator
from sedona.utils import SedonaKryoRegistrator, KryoSerializer

class AirlineDataQuerier:
    """Run queries against an apache spark instance to get Airline info"""
    def __init__(self):
        # Create spark session
        self.spark = SparkSession. \
            builder. \
            appName('Milestone3'). \
            master('local[*]'). \
            config("spark.serializer", KryoSerializer.getName). \
            config("spark.kryo.registrator", SedonaKryoRegistrator.getName). \
            config('spark.jars.packages',
                   'org.apache.sedona:sedona-python-adapter-3.0_2.12:1.0.1-incubating,'
                   'org.datasyslab:geotools-wrapper:geotools-24.1'). \
            getOrCreate()

        SedonaRegistrator.registerAll(self.spark)
        
        self.load_tables()
        
    def load_tables(self):
        """
        Read in tables from data files.
        
        Tables:
        - Airports
        - Airlines
        - states
        - Cities
        - Routes
        """
        # read in airports
        airports = self.spark.read.option("delimiter", ",").option("header", "false").csv("clean_data/airports.csv") \
            .toDF("IDX", "Airport_ID","Name","City","Country","IATA","ICAO","Latitude","Longitude","Altitude","Timezone","DST","Tz_database_timezone","Type","Source")

        airports.createOrReplaceTempView("Airports")
        
        # read in airlines
        airlines = self.spark.read.option("delimiter", ",").option("header", "false").csv("clean_data/airlines.csv") \
            .toDF("IDX","Airline_ID","Name","Alias","IATA","ICAO","Callsign","Country","Active")

        airlines.createOrReplaceTempView("Airlines")
        
        # read in states
        boundary_each_state = self.spark.read.option("delimiter", "\t").option("header", "false").csv("clean_data/boundary-each-state.tsv") \
            .toDF("s_name","s_bound")
        boundary_each_state = boundary_each_state.selectExpr("s_name", "ST_GeomFromWKT(s_bound) as s_bound")
        boundary_each_state.createOrReplaceTempView("states")
        
        # read in cities
        cities = self.spark.read.option("delimiter", ",").option("header", "false").csv("clean_data/cities.csv") \
            .toDF("Name","Longitude","Latitude")

        cities.createOrReplaceTempView("Cities")
        
        # read in routes
        routes = self.spark.read.option("delimiter", ",").option("header", "false").csv("clean_data/routes.csv") \
            .toDF('IDX', 'Airline', 'Airline_ID', 'Source_airport',
               'Source_airport_ID', 'Destination_airport', 'Destination_airport_ID',
               'Codeshare', 'Stops', 'Equipment')

        routes.createOrReplaceTempView("Routes")
    
    def run_query(self, query):
        """Run a query against apache spark instance"""
        return self.spark.sql(query).collect()
    
    def get_airports_in_country(self, country_name):
        """Get a list of Airport_IDs and Names of the airports in country `country_name`"""
        query = f"SELECT Airport_ID, Name FROM airports WHERE Country LIKE '%{country_name}%'"
        return self.run_query(query)
    
    def get_airlines_with_x_stops(self, stop_value):
        """Get a list of Airport_IDs and Names that have `stop_value` stops"""
        query = f"""
        SELECT DISTINCT a.Airline_ID, a.Name, r.stops
        FROM Airlines AS a, Routes AS r
        INNER JOIN Routes ON a.Airline_ID = r.Airline_ID
        WHERE r.Stops = {stop_value}"""
        return self.run_query(query)
    
    def get_airlines_with_code_share(self):
        """Get airlines that have codeshare"""
        query = f"""
        SELECT DISTINCT Airline
        FROM routes
        WHERE Codeshare = 'Y'
        """
        return self.run_query(query)
    
    def get_active_airlines_in_country(self, country_name):
        """Get the airlines that are active in country `country_name`"""
        query = f"""
        SELECT Airline_ID, Name
        FROM Airlines
        WHERE Airlines.Country LIKE '%{country_name}%' AND Airlines.active = 'Y'
        """
        return self.run_query(query)

    def get_active_airlines_in_United_States(self):
        """Get the airlines that are active in United States"""
        return self.get_active_airlines_in_country("United States")
    
    def get_country_or_teritory_with_most_airports(self):
        """Get the country or teritory with the most airports"""
        query = f"""
        SELECT * FROM (
        SELECT COUNT(Airlines.Airline_ID) as number, Airlines.Country
        FROM Airlines
        GROUP BY Airlines.Country)
        ORDER BY number DESC
        LIMIT 1
        """
        return self.run_query(query)
    
    def get_top_k_cities_with_most_incoming_airlines(self, k):
        """Get the top `k` cities with the most incoming airlines"""
        query = f"""
        SELECT count(Routes.airline) as number, Airports.city
        FROM Routes JOIN Airports ON Routes.Destination_airport_ID = Airports.Airport_ID
        GROUP BY Airports.city
        ORDER BY number DESC
        LIMIT {k}
        """
        return self.run_query(query)
    
    def get_closest_airport_to_city(self, city):
        """
        Find the closest airport to `city` and get the Airport_Name, 
        Airport_ID and distance between the city and the airport
        """
        query = f"""
        SELECT SQRT(POW(a_lat - c_lat, 2) + POW(a_long - c_long, 2)) as dist, Airport_Name, Airport_ID
        FROM
        (SELECT a.Latitude as a_lat, a.Longitude as a_long, a.Name as Airport_Name, a.Airport_ID, c.Latitude as c_lat, c.Longitude as c_long
        FROM
        (SELECT Airports.Latitude, Airports.Longitude, Airports.Name, Airports.Airport_ID
        FROM Airports
        WHERE Latitude NOT LIKE 'Latitude' AND Longitude NOT LIKE 'Longitude'
        ) as a 
        INNER JOIN
        (SELECT Cities.Latitude, Cities.Longitude 
        FROM Cities  WHERE Name='{city}' LIMIT 1) as c)
        ORDER BY dist ASC
        LIMIT 1
        """

        return self.run_query(query)
    
    def get_k_closest_airport_to_city(self, city, k):
        """
        Find the k closest airport to `city` and get the Airport_Name, 
        Airport_ID and distance between the city and the airport
        """
        query = f"""
        SELECT POW(a_lat - c_lat, 2) + POW(a_long - c_long, 2) as dist, Airport_Name, Airport_ID
        FROM
        (SELECT a.Latitude as a_lat, a.Longitude as a_long, a.Name as Airport_Name, a.Airport_ID, c.Latitude as c_lat, c.Longitude as c_long
        FROM
        (SELECT Airports.Latitude, Airports.Longitude, Airports.Name, Airports.Airport_ID
        FROM Airports
        WHERE Latitude NOT LIKE 'Latitude' AND Longitude NOT LIKE 'Longitude'
        ) as a 
        INNER JOIN
        (SELECT Cities.Latitude, Cities.Longitude 
        FROM Cities  WHERE Name='{city}' LIMIT 1) as c)
        ORDER BY dist ASC
        LIMIT {k}
        """

        return self.run_query(query)
    
    def get_airport_in_each_state(self):
        """Get the airport in each state, selecting the Airport_ID, Airport_name, and s_name (State name)"""
        query = f"""
        SELECT _contains, Airport_name, Airport_ID, s_name as state_name
        FROM
        (
            SELECT
            ST_Contains(s_bound, c_point) as _contains, Name as Airport_name, Airport_ID, s_name
            FROM
            (
                SELECT * FROM states
            ) AS s
            INNER JOIN
            (
                SELECT ST_GeomFromWKT(CONCAT('POINT(', Longitude, ' ', Latitude, ')')) as c_point, Name, Airport_ID
                FROM Airports 
                WHERE Longitude NOT LIKE 'Longitude' AND Latitude NOT LIKE 'Latitude'
            ) AS c
        )
        WHERE _contains=True
        ORDER BY state_name
        """

        return self.run_query(query)

# %%
querier = AirlineDataQuerier()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/home/sparky/spark-3.0.3-bin-hadoop3.2/jars/spark-unsafe_2.12-3.0.3.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# Ivy Default Cache set to: /home/sparky/.ivy2/cache
# The jars for the packages stored in: /home/sparky/.ivy2/jars
# :: loading settings :: url = jar:file:/home/sparky/spark-3.0.3-bin-hadoop3.2/jars/ivy-2.4.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# org.apache.sedona#sedona-python-adapter-3.0_2.12 added as a dependency
# org.datasyslab#geotools-wrapper added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-fa8fdd28-148e-4bcd-8905-71cd8065c7f8;1.0
# 	confs: [default]
# 	found org.apache.sedona#sedona-python-adapter-3.0_2.12;1.0.1-incubating in central
# 	found org.locationtech.jts#jts-core;1.18.0 in central
# 	found org.wololo#jts2geojson;0.16.1 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.12.2 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.12.2 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.12.2 in central
# 	found org.apache.sedona#sedona-core-3.0_2.12;1.0.1-incubating in central
# 	found org.apache.sedona#sedona-sql-3.0_2.12;1.0.1-incubating in central
# 	found org.datasyslab#geotools-wrapper;geotools-24.1 in central
# :: resolution report :: resolve 597ms :: artifacts dl 20ms
# 	:: modules in use:
# 	com.fasterxml.jackson.core#jackson-annotations;2.12.2 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.12.2 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.2 from central in [default]
# 	org.apache.sedona#sedona-core-3.0_2.12;1.0.1-incubating from central in [default]
# 	org.apache.sedona#sedona-python-adapter-3.0_2.12;1.0.1-incubating from central in [default]
# 	org.apache.sedona#sedona-sql-3.0_2.12;1.0.1-incubating from central in [default]
# 	org.datasyslab#geotools-wrapper;geotools-24.1 from central in [default]
# 	org.locationtech.jts#jts-core;1.18.0 from central in [default]
# 	org.wololo#jts2geojson;0.16.1 from central in [default]
# 	:: evicted modules:
# 	org.locationtech.jts#jts-core;1.18.1 by [org.locationtech.jts#jts-core;1.18.0] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   10  |   0   |   0   |   1   ||   9   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-fa8fdd28-148e-4bcd-8905-71cd8065c7f8
# 	confs: [default]
# 	0 artifacts copied, 9 already retrieved (0kB/19ms)
# 21/12/07 16:42:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 21/12/07 16:42:12 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
querier.get_airlines_with_x_stops(stop_value=1)
# Out:
# [Row(Airline_ID='1316', Name='AirTran Airways', stops='1'),
#  Row(Airline_ID='1936', Name='Cubana de Aviación', stops='1'),
#  Row(Airline_ID='4319', Name='Scandinavian Airlines System', stops='1'),
#  Row(Airline_ID='1623', Name='Canadian North', stops='1'),
#  Row(Airline_ID='330', Name='Air Canada', stops='1'),
#  Row(Airline_ID='4547', Name='Southwest Airlines', stops='1')]

# %%
querier.get_airports_in_country("United States")
# Out:
# [Row(Airport_ID='3411', Name='Barter Island LRRS Airport'),
#  Row(Airport_ID='3412', Name='Wainwright Air Station'),
#  Row(Airport_ID='3413', Name='Cape Lisburne LRRS Airport'),
#  Row(Airport_ID='3414', Name='Point Lay LRRS Airport'),
#  Row(Airport_ID='3415', Name='Hilo International Airport'),
#  Row(Airport_ID='3416', Name='Orlando Executive Airport'),
#  Row(Airport_ID='3417', Name='Bettles Airport'),
#  Row(Airport_ID='3418', Name='Clear Airport'),
#  Row(Airport_ID='3419', Name='Indian Mountain LRRS Airport'),
#  Row(Airport_ID='3420', Name='Fort Yukon Airport'),
#  Row(Airport_ID='3421', Name='Sparrevohn LRRS Airport'),
#  Row(Airport_ID='3422', Name='Bryant Army Heliport'),
#  Row(Airport_ID='3423', Name='Tatalina LRRS Airport'),
#  Row(Airport_ID='3424', Name='Cape Romanzof LRRS Airport'),
#  Row(Airport_ID='3425', Name='Laurence G Hanscom Field'),
#  Row(Airport_ID='3426', Name='St Paul Island Airport'),
#  Row(Airport_ID='3427', Name='Cape Newenham LRRS Airport'),
#  Row(Airport_ID='3428', Name='St George Airport'),
#  Row(Airport_ID='3429', Name='Iliamna Airport'),
#  Row(Airport_ID='3430', Name='Platinum Airport'),
#  Row(Airport_ID='3431', Name='Big Mountain Airport'),
#  Row(Airport_ID='3432', Name='Oscoda Wurtsmith Airport'),
#  Row(Airport_ID='3433', Name='Marina Municipal Airport'),
#  Row(Airport_ID='3434', Name='Sacramento Mather Airport'),
#  Row(Airport_ID='3435', Name='Bicycle Lake Army Air Field'),
#  Row(Airport_ID='3436', Name='Twentynine Palms (Self) Airport'),
#  Row(Airport_ID='3437', Name='Fort Smith Regional Airport'),
#  Row(Airport_ID='3438', Name='Merrill Field'),
#  Row(Airport_ID='3439', Name='Grants-Milan Municipal Airport'),
#  Row(Airport_ID='3440', Name='Ponca City Regional Airport'),
#  Row(Airport_ID='3441', Name='Hunter Army Air Field'),
#  Row(Airport_ID='3442', Name='Grand Forks International Airport'),
#  Row(Airport_ID='3443', Name='Pine Bluff Regional Airport, Grider Field'),
#  Row(Airport_ID='3444', Name='Whiting Field Naval Air Station - North'),
#  Row(Airport_ID='3445', Name='Hana Airport'),
#  Row(Airport_ID='3446', Name='Ernest A. Love Field'),
#  Row(Airport_ID='3447', Name='Trenton Mercer Airport'),
#  Row(Airport_ID='3448', Name='General Edward Lawrence Logan International Airport'),
#  Row(Airport_ID='3449', Name='Travis Air Force Base'),
#  Row(Airport_ID='3450', Name='Griffiss International Airport'),
#  Row(Airport_ID='3451', Name='Wendover Airport'),
#  Row(Airport_ID='3452', Name='Mobile Downtown Airport'),
#  Row(Airport_ID='3453', Name='Metropolitan Oakland International Airport'),
#  Row(Airport_ID='3454', Name='Eppley Airfield'),
#  Row(Airport_ID='3455', Name='Port Angeles Cgas Airport'),
#  Row(Airport_ID='3456', Name='Kahului Airport'),
#  Row(Airport_ID='3457', Name='Wichita Eisenhower National Airport'),
#  Row(Airport_ID='3458', Name='Kansas City International Airport'),
#  Row(Airport_ID='3459', Name='Dane County Regional Truax Field'),
#  Row(Airport_ID='3460', Name='Dillingham Airport'),
#  Row(Airport_ID='3461', Name='Boone County Airport'),
#  Row(Airport_ID='3462', Name='Phoenix Sky Harbor International Airport'),
#  Row(Airport_ID='3463', Name='Bangor International Airport'),
#  Row(Airport_ID='3464', Name='Fort Lauderdale Executive Airport'),
#  Row(Airport_ID='3465', Name='East Texas Regional Airport'),
#  Row(Airport_ID='3466', Name='Anderson Regional Airport'),
#  Row(Airport_ID='3467', Name='Spokane International Airport'),
#  Row(Airport_ID='3468', Name='North Perry Airport'),
#  Row(Airport_ID='3469', Name='San Francisco International Airport'),
#  Row(Airport_ID='3470', Name='Cut Bank International Airport'),
#  Row(Airport_ID='3471', Name='Acadiana Regional Airport'),
#  Row(Airport_ID='3472', Name='Gainesville Regional Airport'),
#  Row(Airport_ID='3473', Name='Memphis International Airport'),
#  Row(Airport_ID='3474', Name='Bisbee Douglas International Airport'),
#  Row(Airport_ID='3475', Name='Allen Army Airfield'),
#  Row(Airport_ID='3476', Name='TSTC Waco Airport'),
#  Row(Airport_ID='3477', Name='Annette Island Airport'),
#  Row(Airport_ID='3478', Name='Caribou Municipal Airport'),
#  Row(Airport_ID='3479', Name='Little Rock Air Force Base'),
#  Row(Airport_ID='3480', Name='Redstone Army Air Field'),
#  Row(Airport_ID='3481', Name='Pope Field'),
#  Row(Airport_ID='3482', Name='Dalhart Municipal Airport'),
#  Row(Airport_ID='3483', Name='DLF Airport'),
#  Row(Airport_ID='3484', Name='Los Angeles International Airport'),
#  Row(Airport_ID='3485', Name='Anniston Regional Airport'),
#  Row(Airport_ID='3486', Name='Cleveland Hopkins International Airport'),
#  Row(Airport_ID='3487', Name='Dover Air Force Base'),
#  Row(Airport_ID='3488', Name='Cincinnati Northern Kentucky International Airport'),
#  Row(Airport_ID='3489', Name='Tipton Airport'),
#  Row(Airport_ID='3490', Name='China Lake Naws (Armitage Field) Airport'),
#  Row(Airport_ID='3491', Name='Huron Regional Airport'),
#  Row(Airport_ID='3492', Name='Juneau International Airport'),
#  Row(Airport_ID='3493', Name='Lafayette Regional Airport'),
#  Row(Airport_ID='3494', Name='Newark Liberty International Airport'),
#  Row(Airport_ID='3495', Name='Boise Air Terminal/Gowen Field'),
#  Row(Airport_ID='3496', Name='Creech Air Force Base'),
#  Row(Airport_ID='3497', Name='Garden City Regional Airport'),
#  Row(Airport_ID='3498', Name='Minot International Airport'),
#  Row(Airport_ID='3499', Name='Wheeler Army Airfield'),
#  Row(Airport_ID='3500', Name='Maxwell Air Force Base'),
#  Row(Airport_ID='3501', Name='Robinson Army Air Field'),
#  Row(Airport_ID='3502', Name='Dallas Love Field'),
#  Row(Airport_ID='3503', Name='Butts AAF (Fort Carson) Air Field'),
#  Row(Airport_ID='3504', Name='Helena Regional Airport'),
#  Row(Airport_ID='3505', Name='Miramar Marine Corps Air Station - Mitscher Field'),
#  Row(Airport_ID='3506', Name='Luke Air Force Base'),
#  Row(Airport_ID='3507', Name='Hurlburt Field'),
#  Row(Airport_ID='3508', Name='Jack Northrop Field Hawthorne Municipal Airport'),
#  Row(Airport_ID='3509', Name='Houlton International Airport'),
#  Row(Airport_ID='3510', Name='Vance Air Force Base'),
#  Row(Airport_ID='3511', Name='Point Mugu Naval Air Station (Naval Base Ventura Co)'),
#  Row(Airport_ID='3512', Name='Edwards Air Force Base'),
#  Row(Airport_ID='3513', Name='Lake Charles Regional Airport'),
#  Row(Airport_ID='3514', Name='Ellison Onizuka Kona International At Keahole Airport'),
#  Row(Airport_ID='3515', Name='Myrtle Beach International Airport'),
#  Row(Airport_ID='3516', Name='Lemoore Naval Air Station (Reeves Field) Airport'),
#  Row(Airport_ID='3517', Name='Nantucket Memorial Airport'),
#  Row(Airport_ID='3518', Name='Felker Army Air Field'),
#  Row(Airport_ID='3519', Name='Campbell AAF (Fort Campbell) Air Field'),
#  Row(Airport_ID='3520', Name='Ronald Reagan Washington National Airport'),
#  Row(Airport_ID='3521', Name='Patuxent River Naval Air Station (Trapnell Field)'),
#  Row(Airport_ID='3522', Name='Palacios Municipal Airport'),
#  Row(Airport_ID='3523', Name='Arkansas International Airport'),
#  Row(Airport_ID='3524', Name='Atlantic City International Airport'),
#  Row(Airport_ID='3525', Name='Tinker Air Force Base'),
#  Row(Airport_ID='3526', Name='Elizabeth City Regional Airport & Coast Guard Air Station'),
#  Row(Airport_ID='3527', Name='Pueblo Memorial Airport'),
#  Row(Airport_ID='3528', Name='Northern Maine Regional Airport at Presque Isle'),
#  Row(Airport_ID='3530', Name='Gray Army Air Field'),
#  Row(Airport_ID='3531', Name='Kodiak Airport'),
#  Row(Airport_ID='3532', Name='Upolu Airport'),
#  Row(Airport_ID='3533', Name='Fort Lauderdale Hollywood International Airport'),
#  Row(Airport_ID='3534', Name='Muskogee-Davis Regional Airport'),
#  Row(Airport_ID='3535', Name='Falls International Airport'),
#  Row(Airport_ID='3536', Name='Salt Lake City International Airport'),
#  Row(Airport_ID='3537', Name='Childress Municipal Airport'),
#  Row(Airport_ID='3538', Name='Keesler Air Force Base'),
#  Row(Airport_ID='3539', Name='Lawson Army Air Field (Fort Benning)'),
#  Row(Airport_ID='3540', Name='Kingsville Naval Air Station'),
#  Row(Airport_ID='3541', Name='Marshall Army Air Field'),
#  Row(Airport_ID='3542', Name='Harrisburg International Airport'),
#  Row(Airport_ID='3543', Name='Lincoln Airport'),
#  Row(Airport_ID='3544', Name='Capital City Airport'),
#  Row(Airport_ID='3545', Name='Waimea Kohala Airport'),
#  Row(Airport_ID='3546', Name='Massena International Richards Field'),
#  Row(Airport_ID='3547', Name='Hickory Regional Airport'),
#  Row(Airport_ID='3548', Name='Albert Whitted Airport'),
#  Row(Airport_ID='3549', Name='Page Field'),
#  Row(Airport_ID='3550', Name='George Bush Intercontinental Houston Airport'),
#  Row(Airport_ID='3551', Name='Millinocket Municipal Airport'),
#  Row(Airport_ID='3552', Name='Joint Base Andrews'),
#  Row(Airport_ID='3553', Name='Smith Reynolds Airport'),
#  Row(Airport_ID='3554', Name='Southern California Logistics Airport'),
#  Row(Airport_ID='3555', Name='Bob Sikes Airport'),
#  Row(Airport_ID='3556', Name='Wheeler Sack Army Air Field'),
#  Row(Airport_ID='3557', Name='St Clair County International Airport'),
#  Row(Airport_ID='3558', Name='Meadows Field'),
#  Row(Airport_ID='3559', Name='El Paso International Airport'),
#  Row(Airport_ID='3560', Name='Valley International Airport'),
#  Row(Airport_ID='3561', Name='Columbia Metropolitan Airport'),
#  Row(Airport_ID='3562', Name='Davis Monthan Air Force Base'),
#  Row(Airport_ID='3563', Name='Pensacola Naval Air Station/Forrest Sherman Field'),
#  Row(Airport_ID='3564', Name='Pensacola Regional Airport'),
#  Row(Airport_ID='3565', Name='Grand Forks Air Force Base'),
#  Row(Airport_ID='3566', Name='William P Hobby Airport'),
#  Row(Airport_ID='3567', Name='Buckley Air Force Base'),
#  Row(Airport_ID='3568', Name='Northway Airport'),
#  Row(Airport_ID='3569', Name='"Warren ""Bud"" Woods Palmer Municipal Airport"'),
#  Row(Airport_ID='3570', Name='Pittsburgh International Airport'),
#  Row(Airport_ID='3571', Name='Wiley Post Will Rogers Memorial Airport'),
#  Row(Airport_ID='3572', Name='Ellington Airport'),
#  Row(Airport_ID='3573', Name='Whidbey Island Naval Air Station (Ault Field)'),
#  Row(Airport_ID='3574', Name='Alice International Airport'),
#  Row(Airport_ID='3575', Name='Moody Air Force Base'),
#  Row(Airport_ID='3576', Name='Miami International Airport'),
#  Row(Airport_ID='3577', Name='Seattle Tacoma International Airport'),
#  Row(Airport_ID='3578', Name='Lovell Field'),
#  Row(Airport_ID='3579', Name='Igor I Sikorsky Memorial Airport'),
#  Row(Airport_ID='3580', Name='Jackson-Medgar Wiley Evers International Airport'),
#  Row(Airport_ID='3581', Name='Scholes International At Galveston Airport'),
#  Row(Airport_ID='3582', Name='Long Beach /Daugherty Field/ Airport'),
#  Row(Airport_ID='3583', Name='Dillingham Airfield'),
#  Row(Airport_ID='3584', Name='Williamsport Regional Airport'),
#  Row(Airport_ID='3585', Name='Indianapolis International Airport'),
#  Row(Airport_ID='3586', Name='Whiteman Air Force Base'),
#  Row(Airport_ID='3587', Name='Akron Fulton International Airport'),
#  Row(Airport_ID='3588', Name='Greenwood–Leflore Airport'),
#  Row(Airport_ID='3589', Name='Westchester County Airport'),
#  Row(Airport_ID='3590', Name='Francis S Gabreski Airport'),
#  Row(Airport_ID='3591', Name='Jonesboro Municipal Airport'),
#  Row(Airport_ID='3592', Name='Tonopah Test Range Airport'),
#  Row(Airport_ID='3593', Name='Palm Beach County Park Airport'),
#  Row(Airport_ID='3594', Name='North Island Naval Air Station-Halsey Field'),
#  Row(Airport_ID='3595', Name='Biggs Army Air Field (Fort Bliss)'),
#  Row(Airport_ID='3596', Name='Yuma MCAS/Yuma International Airport'),
#  Row(Airport_ID='3597', Name='Cavern City Air Terminal'),
#  Row(Airport_ID='3598', Name='Duluth International Airport'),
#  Row(Airport_ID='3599', Name='Bethel Airport'),
#  Row(Airport_ID='3600', Name='Bowman Field'),
#  Row(Airport_ID='3601', Name='Sierra Vista Municipal Libby Army Air Field'),
#  Row(Airport_ID='3602', Name='Lihue Airport'),
#  Row(Airport_ID='3603', Name='Terre Haute Regional Airport, Hulman Field'),
#  Row(Airport_ID='3604', Name='Havre City County Airport'),
#  Row(Airport_ID='3605', Name='Grant County International Airport'),
#  Row(Airport_ID='3606', Name='Edward F Knapp State Airport'),
#  Row(Airport_ID='3607', Name='San Nicolas Island Nolf Airport'),
#  Row(Airport_ID='3608', Name='Richmond International Airport'),
#  Row(Airport_ID='3609', Name='Shreveport Regional Airport'),
#  Row(Airport_ID='3610', Name='Merle K (Mudhole) Smith Airport'),
#  Row(Airport_ID='3611', Name='Norfolk International Airport'),
#  Row(Airport_ID='3612', Name='Southeast Texas Regional Airport'),
#  Row(Airport_ID='3613', Name='Savannah Hilton Head International Airport'),
#  Row(Airport_ID='3614', Name='Hill Air Force Base'),
#  Row(Airport_ID='3615', Name='Nome Airport'),
#  Row(Airport_ID='3616', Name='Scappoose Industrial Airpark'),
#  Row(Airport_ID='3617', Name='St Petersburg Clearwater International Airport'),
#  Row(Airport_ID='3618', Name='Menominee Regional Airport'),
#  Row(Airport_ID='3619', Name='Conroe-North Houston Regional Airport'),
#  Row(Airport_ID='3620', Name='Deadhorse Airport'),
#  Row(Airport_ID='3621', Name='San Antonio International Airport'),
#  Row(Airport_ID='3622', Name='Greater Rochester International Airport'),
#  Row(Airport_ID='3623', Name='Patrick Air Force Base'),
#  Row(Airport_ID='3624', Name='Teterboro Airport'),
#  Row(Airport_ID='3625', Name='Ellsworth Air Force Base'),
#  Row(Airport_ID='3626', Name='Raleigh Durham International Airport'),
#  Row(Airport_ID='3627', Name='James M Cox Dayton International Airport'),
#  Row(Airport_ID='3628', Name='Kenai Municipal Airport'),
#  Row(Airport_ID='3629', Name='Mc Alester Regional Airport'),
#  Row(Airport_ID='3630', Name='Niagara Falls International Airport'),
#  Row(Airport_ID='3631', Name='Coulter Field'),
#  Row(Airport_ID='3632', Name='Wright AAF (Fort Stewart)/Midcoast Regional Airport'),
#  Row(Airport_ID='3633', Name='Newport News Williamsburg International Airport'),
#  Row(Airport_ID='3634', Name='Esler Regional Airport'),
#  Row(Airport_ID='3635', Name='Altus Air Force Base'),
#  Row(Airport_ID='3636', Name='Tucson International Airport'),
#  Row(Airport_ID='3637', Name='Minot Air Force Base'),
#  Row(Airport_ID='3638', Name='Beale Air Force Base'),
#  Row(Airport_ID='3639', Name='Greater Kankakee Airport'),
#  Row(Airport_ID='3640', Name='Seymour Johnson Air Force Base'),
#  Row(Airport_ID='3641', Name='Theodore Francis Green State Airport'),
#  Row(Airport_ID='3642', Name='Salisbury Ocean City Wicomico Regional Airport'),
#  Row(Airport_ID='3643', Name='Rancho Murieta Airport'),
#  Row(Airport_ID='3644', Name='Bob Hope Airport'),
#  Row(Airport_ID='3645', Name='Detroit Metropolitan Wayne County Airport'),
#  Row(Airport_ID='3646', Name='Tampa International Airport'),
#  Row(Airport_ID='3647', Name='Pembina Municipal Airport'),
#  Row(Airport_ID='3648', Name='Polk Army Air Field'),
#  Row(Airport_ID='3649', Name='Eielson Air Force Base'),
#  Row(Airport_ID='3650', Name='Range Regional Airport'),
#  Row(Airport_ID='3651', Name='Angelina County Airport'),
#  Row(Airport_ID='3652', Name='Midland International Airport'),
#  Row(Airport_ID='3653', Name='Austin Straubel International Airport'),
#  Row(Airport_ID='3654', Name='Ardmore Municipal Airport'),
#  Row(Airport_ID='3655', Name='Mc Guire Air Force Base'),
#  Row(Airport_ID='3656', Name='Cherry Point MCAS /Cunningham Field/'),
#  Row(Airport_ID='3657', Name='Emanuel County Airport'),
#  Row(Airport_ID='3658', Name='Augusta Regional At Bush Field'),
#  Row(Airport_ID='3659', Name='Sloulin Field International Airport'),
#  Row(Airport_ID='3660', Name='Bill & Hillary Clinton National Airport/Adams Field'),
#  Row(Airport_ID='3661', Name='Stewart International Airport'),
#  Row(Airport_ID='3662', Name='Baudette International Airport'),
#  Row(Airport_ID='3663', Name='Sacramento Executive Airport'),
#  Row(Airport_ID='3664', Name='Homer Airport'),
#  Row(Airport_ID='3665', Name='Waynesville-St. Robert Regional Forney field'),
#  Row(Airport_ID='3666', Name='Dobbins Air Reserve Base'),
#  Row(Airport_ID='3667', Name='Fairchild Air Force Base'),
#  Row(Airport_ID='3668', Name='Roscommon County - Blodgett Memorial Airport'),
#  Row(Airport_ID='3669', Name='Tyndall Air Force Base'),
#  Row(Airport_ID='3670', Name='Dallas Fort Worth International Airport'),
#  Row(Airport_ID='3671', Name='Melbourne International Airport'),
#  Row(Airport_ID='3672', Name='McChord Air Force Base'),
#  Row(Airport_ID='3673', Name='Austin Bergstrom International Airport'),
#  Row(Airport_ID='3674', Name='Rickenbacker International Airport'),
#  Row(Airport_ID='3675', Name='Sawyer International Airport'),
#  Row(Airport_ID='3676', Name='McGhee Tyson Airport'),
#  Row(Airport_ID='3677', Name='Hood Army Air Field'),
#  Row(Airport_ID='3678', Name='St Louis Lambert International Airport'),
#  Row(Airport_ID='3679', Name='Millville Municipal Airport'),
#  Row(Airport_ID='3680', Name='Sheppard Air Force Base-Wichita Falls Municipal Airport'),
#  Row(Airport_ID='3681', Name='Cincinnati Municipal Airport Lunken Field'),
#  Row(Airport_ID='3682', Name='Hartsfield Jackson Atlanta International Airport'),
#  Row(Airport_ID='3683', Name='Castle Airport'),
#  Row(Airport_ID='3684', Name='Mc Clellan Airfield'),
#  Row(Airport_ID='3685', Name='Gerald R. Ford International Airport'),
#  Row(Airport_ID='3686', Name='Winkler County Airport'),
#  Row(Airport_ID='3687', Name='Fresno Yosemite International Airport'),
#  Row(Airport_ID='3688', Name='Vero Beach Regional Airport'),
#  Row(Airport_ID='3689', Name='Imperial County Airport'),
#  Row(Airport_ID='3690', Name='Nashville International Airport'),
#  Row(Airport_ID='3691', Name='Laredo International Airport'),
#  Row(Airport_ID='3692', Name='Elmendorf Air Force Base'),
#  Row(Airport_ID='3693', Name='Ralph Wien Memorial Airport'),
#  Row(Airport_ID='3694', Name='Altoona Blair County Airport'),
#  Row(Airport_ID='3695', Name='Dyess Air Force Base'),
#  Row(Airport_ID='3696', Name='South Arkansas Regional At Goodwin Field'),
#  Row(Airport_ID='3697', Name='La Guardia Airport'),
#  Row(Airport_ID='3698', Name='Tallahassee Regional Airport'),
#  Row(Airport_ID='3699', Name='Dupage Airport'),
#  Row(Airport_ID='3700', Name='Waco Regional Airport'),
#  Row(Airport_ID='3701', Name='Augusta State Airport'),
#  Row(Airport_ID='3702', Name='Hillsboro Municipal Airport'),
#  Row(Airport_ID='3703', Name='Jacksonville Naval Air Station (Towers Field)'),
#  Row(Airport_ID='3704', Name='McKellar-Sipes Regional Airport'),
#  Row(Airport_ID='3705', Name='Molokai Airport'),
#  Row(Airport_ID='3706', Name='Godman Army Air Field'),
#  Row(Airport_ID='3707', Name='New River MCAS /H/ /Mccutcheon Fld/ Airport'),
#  Row(Airport_ID='3708', Name='San Angelo Regional Mathis Field'),
#  Row(Airport_ID='3709', Name='Calexico International Airport'),
#  Row(Airport_ID='3710', Name='Chico Municipal Airport'),
#  Row(Airport_ID='3711', Name='Burlington International Airport'),
#  Row(Airport_ID='3712', Name='Jacksonville International Airport'),
#  Row(Airport_ID='3713', Name='Durango La Plata County Airport'),
#  Row(Airport_ID='3714', Name='Washington Dulles International Airport'),
#  Row(Airport_ID='3715', Name='Easterwood Field'),
#  Row(Airport_ID='3716', Name='Felts Field'),
#  Row(Airport_ID='3717', Name='General Mitchell International Airport'),
#  Row(Airport_ID='3718', Name='Abilene Regional Airport'),
#  Row(Airport_ID='3719', Name='Columbia Regional Airport'),
#  Row(Airport_ID='3720', Name='Portland International Airport'),
#  Row(Airport_ID='3721', Name='Dade Collier Training and Transition Airport'),
#  Row(Airport_ID='3722', Name='Palm Beach International Airport'),
#  Row(Airport_ID='3723', Name='Fort Worth Meacham International Airport'),
#  Row(Airport_ID='3724', Name='Ogdensburg International Airport'),
#  Row(Airport_ID='3725', Name='Cape Cod Coast Guard Air Station'),
#  Row(Airport_ID='3726', Name='Boeing Field King County International Airport'),
#  Row(Airport_ID='3727', Name='Lackland Air Force Base'),
#  Row(Airport_ID='3728', Name='Daniel K Inouye International Airport'),
#  Row(Airport_ID='3729', Name='Des Moines International Airport'),
#  Row(Airport_ID='3730', Name='Coastal Carolina Regional Airport'),
#  Row(Airport_ID='3731', Name='San Diego International Airport'),
#  Row(Airport_ID='3732', Name='Monroe Regional Airport'),
#  Row(Airport_ID='3733', Name='Shaw Air Force Base'),
#  Row(Airport_ID='3734', Name='Ontario International Airport'),
#  Row(Airport_ID='3735', Name='Majors Airport'),
#  Row(Airport_ID='3736', Name='Roswell International Air Center Airport'),
#  Row(Airport_ID='3737', Name='Coleman A. Young Municipal Airport'),
#  Row(Airport_ID='3738', Name='Brownsville South Padre Island International Airport'),
#  Row(Airport_ID='3739', Name='Dothan Regional Airport'),
#  Row(Airport_ID='3740', Name='Cape May County Airport'),
#  Row(Airport_ID='3741', Name='Fallon Naval Air Station'),
#  Row(Airport_ID='3742', Name='Selfridge Air National Guard Base Airport'),
#  Row(Airport_ID='3743', Name='Four Corners Regional Airport'),
#  Row(Airport_ID='3744', Name='Corpus Christi International Airport'),
#  Row(Airport_ID='3745', Name='Syracuse Hancock International Airport'),
#  Row(Airport_ID='3746', Name='Naval Air Station Key West/Boca Chica Field'),
#  Row(Airport_ID='3747', Name='Chicago Midway International Airport'),
#  Row(Airport_ID='3748', Name='Norman Y. Mineta San Jose International Airport'),
#  Row(Airport_ID='3749', Name='Lea County Regional Airport'),
#  Row(Airport_ID='3750', Name='Northeast Philadelphia Airport'),
#  Row(Airport_ID='3751', Name='Denver International Airport'),
#  Row(Airport_ID='3752', Name='Philadelphia International Airport'),
#  Row(Airport_ID='3753', Name='Sioux Gateway Col. Bud Day Field'),
#  Row(Airport_ID='3754', Name='Middle Georgia Regional Airport'),
#  Row(Airport_ID='3755', Name='Truth Or Consequences Municipal Airport'),
#  Row(Airport_ID='3756', Name='Palmdale Regional/USAF Plant 42 Airport'),
#  Row(Airport_ID='3757', Name='Randolph Air Force Base'),
#  Row(Airport_ID='3758', Name='El Centro NAF Airport (Vraciu Field)'),
#  Row(Airport_ID='3759', Name='John Glenn Columbus International Airport'),
#  Row(Airport_ID='3760', Name='Drake Field'),
#  Row(Airport_ID='3761', Name='Henry Post Army Air Field (Fort Sill)'),
#  Row(Airport_ID='3762', Name='Princeton Municipal Airport'),
#  Row(Airport_ID='3763', Name='Wright-Patterson Air Force Base'),
#  Row(Airport_ID='3764', Name='Edward G. Pitka Sr Airport'),
#  Row(Airport_ID='3765', Name='Chandler Municipal Airport'),
#  Row(Airport_ID='3766', Name='Mineral Wells Airport'),
#  Row(Airport_ID='3767', Name='Mc Connell Air Force Base'),
#  Row(Airport_ID='3768', Name='New Orleans NAS JRB/Alvin Callender Field'),
#  Row(Airport_ID='3769', Name='Beaufort County Airport'),
#  Row(Airport_ID='3770', Name='Texarkana Regional Webb Field'),
#  Row(Airport_ID='3771', Name='Plattsburgh International Airport'),
#  Row(Airport_ID='3772', Name='Phillips Army Air Field'),
#  Row(Airport_ID='3773', Name='Tucumcari Municipal Airport'),
#  Row(Airport_ID='3774', Name='Ted Stevens Anchorage International Airport'),
#  Row(Airport_ID='3775', Name='Robert Gray  Army Air Field Airport'),
#  Row(Airport_ID='3776', Name='Black Rock Airport'),
#  Row(Airport_ID='3777', Name='Bellingham International Airport'),
#  Row(Airport_ID='3778', Name='Millington-Memphis Airport'),
#  Row(Airport_ID='3779', Name='Elkins-Randolph Co-Jennings Randolph Field'),
#  Row(Airport_ID='3780', Name='Hartford Brainard Airport'),
#  Row(Airport_ID='3781', Name='North Central State Airport'),
#  Row(Airport_ID='3782', Name='Mobile Regional Airport'),
#  Row(Airport_ID='3783', Name='Moffett Federal Airfield'),
#  Row(Airport_ID='3784', Name='Santa Fe Municipal Airport'),
#  Row(Airport_ID='3785', Name='Barking Sands Airport'),
#  Row(Airport_ID='3786', Name='Beauregard Regional Airport'),
#  Row(Airport_ID='3787', Name='Bradshaw Army Airfield'),
#  Row(Airport_ID='3788', Name='Nogales International Airport'),
#  Row(Airport_ID='3789', Name='Mac Dill Air Force Base'),
#  Row(Airport_ID='3790', Name='Scott AFB/Midamerica Airport'),
#  Row(Airport_ID='3791', Name='Opa-locka Executive Airport'),
#  Row(Airport_ID='3792', Name='Del Rio International Airport'),
#  Row(Airport_ID='3793', Name='Southwest Florida International Airport'),
#  Row(Airport_ID='3794', Name='King Salmon Airport'),
#  Row(Airport_ID='3795', Name='Muir Army Air Field (Fort Indiantown Gap) Airport'),
#  Row(Airport_ID='3796', Name='Kapalua Airport'),
#  Row(Airport_ID='3797', Name='John F Kennedy International Airport'),
#  Row(Airport_ID='3798', Name='Homestead ARB Airport'),
#  Row(Airport_ID='3799', Name='Riverside Municipal Airport'),
#  Row(Airport_ID='3800', Name='Sherman Army Air Field'),
#  Row(Airport_ID='3801', Name='Wallops Flight Facility Airport'),
#  Row(Airport_ID='3802', Name='Holloman Air Force Base'),
#  Row(Airport_ID='3803', Name='Willow Grove Naval Air Station/Joint Reserve Base'),
#  Row(Airport_ID='3804', Name='Cheyenne Regional Jerry Olson Field'),
#  Row(Airport_ID='3805', Name='Stockton Metropolitan Airport'),
#  Row(Airport_ID='3806', Name='Charleston Air Force Base-International Airport'),
#  Row(Airport_ID='3807', Name='Reno Tahoe International Airport'),
#  Row(Airport_ID='3808', Name='Ketchikan International Airport'),
#  Row(Airport_ID='3809', Name='Willow Run Airport'),
#  Row(Airport_ID='3810', Name='Vandenberg Air Force Base'),
#  Row(Airport_ID='3811', Name='Birmingham-Shuttlesworth International Airport'),
#  Row(Airport_ID='3812', Name='Lakehurst Maxfield Field Airport'),
#  Row(Airport_ID='3813', Name='Eareckson Air Station'),
#  Row(Airport_ID='3814', Name='Nellis Air Force Base'),
#  Row(Airport_ID='3815', Name='March ARB Airport'),
#  Row(Airport_ID='3816', Name='Modesto City Co-Harry Sham Field'),
#  Row(Airport_ID='3817', Name='Sacramento International Airport'),
#  Row(Airport_ID='3818', Name='Waukegan National Airport'),
#  Row(Airport_ID='3819', Name='City of Colorado Springs Municipal Airport'),
#  Row(Airport_ID='3820', Name='Buffalo Niagara International Airport'),
#  Row(Airport_ID='3821', Name='Griffing Sandusky Airport'),
#  Row(Airport_ID='3822', Name='Snohomish County (Paine Field) Airport'),
#  Row(Airport_ID='3823', Name='Mountain Home Air Force Base'),
#  Row(Airport_ID='3824', Name='Cedar City Regional Airport'),
#  Row(Airport_ID='3825', Name='Bradley International Airport'),
#  Row(Airport_ID='3826', Name='Mc Allen Miller International Airport'),
#  Row(Airport_ID='3827', Name='Norfolk Naval Station (Chambers Field)'),
#  Row(Airport_ID='3828', Name='Westover ARB/Metropolitan Airport'),
#  Row(Airport_ID='3829', Name='Lubbock Preston Smith International Airport'),
#  Row(Airport_ID='3830', Name="Chicago O'Hare International Airport"),
#  Row(Airport_ID='3831', Name='Boca Raton Airport'),
#  Row(Airport_ID='3832', Name='Fairbanks International Airport'),
#  Row(Airport_ID='3833', Name='Quantico MCAF /Turner field'),
#  Row(Airport_ID='3834', Name='Cannon Air Force Base'),
#  Row(Airport_ID='3835', Name='Kaneohe Bay MCAS (Marion E. Carl Field) Airport'),
#  Row(Airport_ID='3836', Name='Offutt Air Force Base'),
#  Row(Airport_ID='3837', Name='Gulkana Airport'),
#  Row(Airport_ID='3838', Name='Watertown International Airport'),
#  Row(Airport_ID='3839', Name='Palm Springs International Airport'),
#  Row(Airport_ID='3840', Name='Rick Husband Amarillo International Airport'),
#  Row(Airport_ID='3841', Name='Fort Dodge Regional Airport'),
#  Row(Airport_ID='3842', Name='Barksdale Air Force Base'),
#  Row(Airport_ID='3843', Name='Topeka Regional Airport - Forbes Field'),
#  Row(Airport_ID='3844', Name='Cotulla-La Salle County Airport'),
#  Row(Airport_ID='3845', Name='Wilmington International Airport'),
#  Row(Airport_ID='3846', Name='Baton Rouge Metropolitan Airport'),
#  Row(Airport_ID='3847', Name='Meridian Naval Air Station'),
#  Row(Airport_ID='3848', Name='Tyler Pounds Regional Airport'),
#  Row(Airport_ID='3849', Name='Baltimore/Washington International Thurgood Marshall Airport'),
#  Row(Airport_ID='3850', Name='Hobart Regional Airport'),
#  Row(Airport_ID='3851', Name='Lanai Airport'),
#  Row(Airport_ID='3852', Name='Alexandria International Airport'),
#  Row(Airport_ID='3853', Name='Condron Army Air Field'),
#  Row(Airport_ID='3854', Name='Cold Bay Airport'),
#  Row(Airport_ID='3855', Name='Tulsa International Airport'),
#  Row(Airport_ID='3856', Name='Sitka Rocky Gutierrez Airport'),
#  Row(Airport_ID='3857', Name='Long Island Mac Arthur Airport'),
#  Row(Airport_ID='3858', Name='Minneapolis-St Paul International/Wold-Chamberlain Airport'),
#  Row(Airport_ID='3859', Name='New Castle Airport'),
#  Row(Airport_ID='3860', Name='Unalaska Airport'),
#  Row(Airport_ID='3861', Name='Louis Armstrong New Orleans International Airport'),
#  Row(Airport_ID='3862', Name='Portland International Jetport Airport'),
#  Row(Airport_ID='3863', Name='Will Rogers World Airport'),
#  Row(Airport_ID='3864', Name='Albany International Airport'),
#  Row(Airport_ID='3865', Name='Valdez Pioneer Field'),
#  Row(Airport_ID='3866', Name='Langley Air Force Base'),
#  Row(Airport_ID='3867', Name='John Wayne Airport-Orange County Airport'),
#  Row(Airport_ID='3868', Name='Columbus Air Force Base'),
#  Row(Airport_ID='3869', Name='Kendall-Tamiami Executive Airport'),
#  Row(Airport_ID='3870', Name='Oceana Naval Air Station'),
#  Row(Airport_ID='3871', Name='Grissom Air Reserve Base'),
#  Row(Airport_ID='3872', Name='Casper-Natrona County International Airport'),
#  Row(Airport_ID='3873', Name='Destin-Ft Walton Beach Airport'),
#  Row(Airport_ID='3874', Name='Craig Field'),
#  Row(Airport_ID='3875', Name='Key West International Airport'),
#  Row(Airport_ID='3876', Name='Charlotte Douglas International Airport'),
#  Row(Airport_ID='3877', Name='McCarran International Airport'),
#  Row(Airport_ID='3878', Name='Orlando International Airport'),
#  Row(Airport_ID='3879', Name='Florence Regional Airport'),
#  Row(Airport_ID='3880', Name='Great Falls International Airport'),
#  Row(Airport_ID='3881', Name='Youngstown Warren Regional Airport'),
#  Row(Airport_ID='3882', Name='Ladd AAF Airfield'),
#  Row(Airport_ID='3883', Name='Mc Minnville Municipal Airport'),
#  Row(Airport_ID='3884', Name='Robins Air Force Base'),
#  Row(Airport_ID='3944', Name='Pullman Moscow Regional Airport'),
#  Row(Airport_ID='3945', Name='Lewiston Nez Perce County Airport'),
#  Row(Airport_ID='3946', Name='Elmira Corning Regional Airport'),
#  Row(Airport_ID='3947', Name='Ithaca Tompkins Regional Airport'),
#  Row(Airport_ID='3948', Name='Monterey Peninsula Airport'),
#  Row(Airport_ID='3949', Name='Santa Barbara Municipal Airport'),
#  Row(Airport_ID='3950', Name='Daytona Beach International Airport'),
#  Row(Airport_ID='3993', Name='Downtown-Manhattan/Wall St Heliport'),
#  Row(Airport_ID='4004', Name='Talkeetna Airport'),
#  Row(Airport_ID='4006', Name='Tweed New Haven Airport'),
#  Row(Airport_ID='4007', Name='Asheville Regional Airport'),
#  Row(Airport_ID='4008', Name='Piedmont Triad International Airport'),
#  Row(Airport_ID='4009', Name='Joe Foss Field Airport'),
#  Row(Airport_ID='4011', Name='Manchester-Boston Regional Airport'),
#  Row(Airport_ID='4012', Name='Naples Municipal Airport'),
#  Row(Airport_ID='4014', Name='Louisville International Standiford Field'),
#  Row(Airport_ID='4015', Name='Charlottesville Albemarle Airport'),
#  Row(Airport_ID='4016', Name='Roanoke–Blacksburg Regional Airport'),
#  Row(Airport_ID='4017', Name='Blue Grass Airport'),
#  Row(Airport_ID='4018', Name='Evansville Regional Airport'),
#  Row(Airport_ID='4019', Name='Albuquerque International Sunport'),
#  Row(Airport_ID='4020', Name='Gallatin Field'),
#  Row(Airport_ID='4021', Name='Billings Logan International Airport'),
#  Row(Airport_ID='4022', Name='Bert Mooney Airport'),
#  Row(Airport_ID='4023', Name='Cherry Capital Airport'),
#  Row(Airport_ID='4025', Name='Hancock County-Bar Harbor Airport'),
#  Row(Airport_ID='4026', Name='Knox County Regional Airport'),
#  Row(Airport_ID='4027', Name='Jackson Hole Airport'),
#  Row(Airport_ID='4028', Name='Chicago Rockford International Airport'),
#  Row(Airport_ID='4034', Name='Greenville Spartanburg International Airport'),
#  Row(Airport_ID='4037', Name='Central Illinois Regional Airport at Bloomington-Normal'),
#  Row(Airport_ID='4038', Name='Gulfport Biloxi International Airport'),
#  Row(Airport_ID='4039', Name='Kalamazoo Battle Creek International Airport'),
#  Row(Airport_ID='4040', Name='Toledo Express Airport'),
#  Row(Airport_ID='4041', Name='Fort Wayne International Airport'),
#  Row(Airport_ID='4042', Name='Decatur Airport'),
#  Row(Airport_ID='4043', Name='The Eastern Iowa Airport'),
#  Row(Airport_ID='4044', Name='La Crosse Municipal Airport'),
#  Row(Airport_ID='4045', Name='Central Wisconsin Airport'),
#  Row(Airport_ID='4046', Name='General Wayne A. Downing Peoria International Airport'),
#  Row(Airport_ID='4047', Name='Appleton International Airport'),
#  Row(Airport_ID='4048', Name='Rochester International Airport'),
#  Row(Airport_ID='4049', Name='University of Illinois Willard Airport'),
#  Row(Airport_ID='4050', Name='Manhattan Regional Airport'),
#  Row(Airport_ID='4058', Name='Venango Regional Airport'),
#  Row(Airport_ID='4063', Name='Grand Junction Regional Airport'),
#  Row(Airport_ID='4064', Name='St George Municipal Airport'),
#  Row(Airport_ID='4065', Name='David Wayne Hooks Memorial Airport'),
#  Row(Airport_ID='4066', Name="Port O'Connor Private Heliport"),
#  Row(Airport_ID='4067', Name='Sarasota Bradenton International Airport'),
#  Row(Airport_ID='4071', Name='Van Nuys Airport'),
#  Row(Airport_ID='4072', Name='Quad City International Airport'),
#  Row(Airport_ID='4073', Name='Panama City-Bay Co International Airport'),
#  Row(Airport_ID='4083', Name='Bismarck Municipal Airport'),
#  Row(Airport_ID='4084', Name='Telluride Regional Airport'),
#  Row(Airport_ID='4087', Name='Rapid City Regional Airport'),
#  Row(Airport_ID='4088', Name='Mc Clellan-Palomar Airport'),
#  Row(Airport_ID='4089', Name='Bishop International Airport'),
#  Row(Airport_ID='4098', Name='Redding Municipal Airport'),
#  Row(Airport_ID='4099', Name='Mahlon Sweet Field'),
#  Row(Airport_ID='4100', Name='Idaho Falls Regional Airport'),
#  Row(Airport_ID='4101', Name='Rogue Valley International Medford Airport'),
#  Row(Airport_ID='4103', Name='Roberts Field'),
#  Row(Airport_ID='4112', Name='Akron Canton Regional Airport'),
#  Row(Airport_ID='4113', Name='Huntsville International Carl T Jones Field'),
#  Row(Airport_ID='4114', Name='Mid Ohio Valley Regional Airport'),
#  Row(Airport_ID='4115', Name='Montgomery Regional (Dannelly Field) Airport'),
#  Row(Airport_ID='4116', Name='Tri-Cities Regional TN/VA Airport'),
#  Row(Airport_ID='4117', Name='Barkley Regional Airport'),
#  Row(Airport_ID='4124', Name='Page Municipal Airport'),
#  Row(Airport_ID='4127', Name='Glacier Park International Airport'),
#  Row(Airport_ID='4128', Name='MBS International Airport'),
#  Row(Airport_ID='4129', Name='Greater Binghamton/Edwin A Link field'),
#  Row(Airport_ID='4136', Name='Blythe Airport'),
#  Row(Airport_ID='4147', Name='Petersburg James A Johnson Airport'),
#  Row(Airport_ID='4167', Name='Orlando Sanford International Airport'),
#  Row(Airport_ID='4169', Name='John Murtha Johnstown Cambria County Airport'),
#  Row(Airport_ID='4216', Name='Missoula International Airport'),
#  Row(Airport_ID='4219', Name='Grand Canyon National Park Airport'),
#  Row(Airport_ID='4220', Name='Sugar Land Regional Airport'),
#  Row(Airport_ID='4222', Name='Centennial Airport'),
#  Row(Airport_ID='4223', Name='Clovis Municipal Airport'),
#  Row(Airport_ID='4224', Name='Fort Stockton Pecos County Airport'),
#  Row(Airport_ID='4225', Name='Las Vegas Municipal Airport'),
#  Row(Airport_ID='4226', Name='West Houston Airport'),
#  Row(Airport_ID='4227', Name='La Junta Municipal Airport'),
#  Row(Airport_ID='4228', Name='Las Cruces International Airport'),
#  Row(Airport_ID='4229', Name='Stephens County Airport'),
#  Row(Airport_ID='4230', Name='Draughon Miller Central Texas Regional Airport'),
#  Row(Airport_ID='4231', Name='Ozona Municipal Airport'),
#  Row(Airport_ID='4250', Name='Eagle County Regional Airport'),
#  Row(Airport_ID='4253', Name='Cuyahoga County Airport'),
#  Row(Airport_ID='4254', Name='Mansfield Lahm Regional Airport'),
#  Row(Airport_ID='4255', Name='Columbus Metropolitan Airport'),
#  Row(Airport_ID='4256', Name='Lawton Fort Sill Regional Airport'),
#  Row(Airport_ID='4257', Name='Northern Colorado Regional Airport'),
#  Row(Airport_ID='4261', Name='Flagstaff Pulliam Airport'),
#  Row(Airport_ID='4262', Name='Lake Tahoe Airport'),
#  Row(Airport_ID='4263', Name='Joslin Field Magic Valley Regional Airport'),
#  Row(Airport_ID='4265', Name="Martha's Vineyard Airport"),
#  Row(Airport_ID='4268', Name='Concord Municipal Airport'),
#  Row(Airport_ID='4270', Name='Groton New London Airport'),
#  Row(Airport_ID='4271', Name='St Cloud Regional Airport'),
#  Row(Airport_ID='4273', Name='Golden Triangle Regional Airport'),
#  Row(Airport_ID='4275', Name='Bowerman Airport'),
#  Row(Airport_ID='4276', Name='Erie International Tom Ridge Field'),
#  Row(Airport_ID='4278', Name='Barnstable Municipal Boardman Polando Field'),
#  Row(Airport_ID='4280', Name='Sedona Airport'),
#  Row(Airport_ID='4284', Name='Morgantown Municipal Walter L. Bill Hart Field'),
#  Row(Airport_ID='4285', Name='Yeager Airport'),
#  Row(Airport_ID='4286', Name='Wilkes Barre Scranton International Airport'),
#  Row(Airport_ID='4287', Name='Bemidji Regional Airport'),
#  Row(Airport_ID='4292', Name='Hector International Airport'),
#  Row(Airport_ID='4293', Name='Charles B. Wheeler Downtown Airport'),
#  Row(Airport_ID='4296', Name='Gillette Campbell County Airport'),
#  Row(Airport_ID='4298', Name='El Toro Marine Corps Air Station'),
#  Row(Airport_ID='4318', Name='University Park Airport'),
#  Row(Airport_ID='4335', Name='Key Field'),
#  Row(Airport_ID='4336', Name='Abraham Lincoln Capital Airport'),
#  Row(Airport_ID='4338', Name='Cortez Municipal Airport'),
#  Row(Airport_ID='4339', Name='Yampa Valley Airport'),
#  Row(Airport_ID='4340', Name='Gallup Municipal Airport'),
#  Row(Airport_ID='4341', Name='Liberal Mid-America Regional Airport'),
#  Row(Airport_ID='4342', Name='Lamar Municipal Airport'),
#  Row(Airport_ID='4343', Name='Renner Field-Goodland Municipal Airport'),
#  Row(Airport_ID='4344', Name='Yellowstone Regional Airport'),
#  Row(Airport_ID='4348', Name='Springfield Branson National Airport'),
#  Row(Airport_ID='4354', Name='Joplin Regional Airport'),
#  Row(Airport_ID='4355', Name='Lehigh Valley International Airport'),
#  Row(Airport_ID='4356', Name='Northwest Arkansas Regional Airport'),
#  Row(Airport_ID='4359', Name='South Bend Regional Airport'),
#  Row(Airport_ID='4383', Name='Smith Field'),
#  Row(Airport_ID='4384', Name='California Redwood Coast-Humboldt County Airport'),
#  Row(Airport_ID='4386', Name='Albert J Ellis Airport'),
#  Row(Airport_ID='4387', Name='Tuscaloosa Regional Airport'),
#  Row(Airport_ID='4388', Name='Dubuque Regional Airport'),
#  Row(Airport_ID='5714', Name='Aberdeen Regional Airport'),
#  Row(Airport_ID='5715', Name='Southwest Georgia Regional Airport'),
#  Row(Airport_ID='5716', Name='Athens Ben Epps Airport'),
#  Row(Airport_ID='5717', Name='Alamogordo White Sands Regional Airport'),
#  Row(Airport_ID='5718', Name='Waterloo Regional Airport'),
#  Row(Airport_ID='5719', Name='Walla Walla Regional Airport'),
#  Row(Airport_ID='5720', Name='Alpena County Regional Airport'),
#  Row(Airport_ID='5721', Name='Watertown Regional Airport'),
#  Row(Airport_ID='5722', Name='Bradford Regional Airport'),
#  Row(Airport_ID='5723', Name='Western Neb. Rgnl/William B. Heilig Airport'),
#  Row(Airport_ID='5724', Name='Raleigh County Memorial Airport'),
#  Row(Airport_ID='5725', Name='Brunswick Golden Isles Airport'),
#  Row(Airport_ID='5726', Name='Southeast Iowa Regional Airport'),
#  Row(Airport_ID='5727', Name='Jack Mc Namara Field Airport'),
#  Row(Airport_ID='5728', Name='Cape Girardeau Regional Airport'),
#  Row(Airport_ID='5729', Name='Chippewa County International Airport'),
#  Row(Airport_ID='5730', Name='North Central West Virginia Airport'),
#  Row(Airport_ID='5731', Name='William R Fairchild International Airport'),
#  Row(Airport_ID='5732', Name='Houghton County Memorial Airport'),
#  Row(Airport_ID='5733', Name='Dodge City Regional Airport'),
#  Row(Airport_ID='5734', Name='DuBois Regional Airport'),
#  Row(Airport_ID='5735', Name='Chippewa Valley Regional Airport'),
#  Row(Airport_ID='5736', Name='Elko Regional Airport'),
#  Row(Airport_ID='5737', Name='New Bedford Regional Airport'),
#  Row(Airport_ID='5738', Name='Fayetteville Regional Grannis Field'),
#  Row(Airport_ID='5739', Name='Wokal Field Glasgow International Airport'),
#  Row(Airport_ID='5740', Name='Central Nebraska Regional Airport'),
#  Row(Airport_ID='5741', Name='Memorial Field'),
#  Row(Airport_ID='5742', Name='Tri-State/Milton J. Ferguson Field'),
#  Row(Airport_ID='5744', Name='Kirksville Regional Airport'),
#  Row(Airport_ID='5745', Name='Jamestown Regional Airport'),
#  Row(Airport_ID='5746', Name='Laramie Regional Airport'),
#  Row(Airport_ID='5747', Name='Arnold Palmer Regional Airport'),
#  Row(Airport_ID='5748', Name='North Platte Regional Airport Lee Bird Field'),
#  Row(Airport_ID='5749', Name='Lebanon Municipal Airport'),
#  Row(Airport_ID='5750', Name='Crater Lake-Klamath Regional Airport'),
#  Row(Airport_ID='5751', Name='Lancaster Airport'),
#  Row(Airport_ID='5752', Name='Lewistown Municipal Airport'),
#  Row(Airport_ID='5753', Name='Lynchburg Regional Preston Glenn Field'),
#  Row(Airport_ID='5754', Name='Muskegon County Airport'),
#  Row(Airport_ID='5755', Name='Frank Wiley Field'),
#  Row(Airport_ID='5756', Name='Northwest Alabama Regional Airport'),
#  Row(Airport_ID='5757', Name='Southwest Oregon Regional Airport'),
#  Row(Airport_ID='5758', Name='Owensboro Daviess County Airport'),
#  Row(Airport_ID='5759', Name='Hattiesburg Laurel Regional Airport'),
#  Row(Airport_ID='5760', Name='Pocatello Regional Airport'),
#  Row(Airport_ID='5761', Name='Pierre Regional Airport'),
#  Row(Airport_ID='5762', Name='Pellston Regional Airport of Emmet County Airport'),
#  Row(Airport_ID='5763', Name='Portsmouth International at Pease Airport'),
#  Row(Airport_ID='5764', Name='Reading Regional Carl A Spaatz Field'),
#  Row(Airport_ID='5765', Name='Rhinelander Oneida County Airport'),
#  Row(Airport_ID='5766', Name='Southwest Wyoming Regional Airport'),
#  Row(Airport_ID='5767', Name='Rutland - Southern Vermont Regional Airport'),
#  Row(Airport_ID='5768', Name='San Luis County Regional Airport'),
#  Row(Airport_ID='5769', Name='Sheridan County Airport'),
#  Row(Airport_ID='5770', Name='Adirondack Regional Airport'),
#  Row(Airport_ID='5771', Name='Salina Municipal Airport'),
#  Row(Airport_ID='5772', Name='Santa Maria Pub/Capt G Allan Hancock Field'),
#  Row(Airport_ID='5773', Name='Tupelo Regional Airport'),
#  Row(Airport_ID='5774', Name='Quincy Regional Baldwin Field'),
#  Row(Airport_ID='5775', Name='Victoria Regional Airport'),
#  Row(Airport_ID='5776', Name='Valdosta Regional Airport'),
#  Row(Airport_ID='5777', Name='Worland Municipal Airport'),
#  Row(Airport_ID='5779', Name='Yakima Air Terminal McAllister Field'),
#  Row(Airport_ID='5959', Name='Adak Airport'),
#  Row(Airport_ID='5960', Name='Gustavus Airport'),
#  Row(Airport_ID='5961', Name='Skagway Airport'),
#  Row(Airport_ID='5962', Name='Holy Cross Airport'),
#  Row(Airport_ID='5963', Name='Haines Airport'),
#  Row(Airport_ID='5964', Name='Kalskag Airport'),
#  Row(Airport_ID='5965', Name='McGrath Airport'),
#  Row(Airport_ID='5966', Name='Mountain Village Airport'),
#  Row(Airport_ID='5967', Name='Aniak Airport'),
#  Row(Airport_ID='5968', Name='Chevak Airport'),
#  Row(Airport_ID='5969', Name='Wrangell Airport'),
#  Row(Airport_ID='5989', Name='Kalaupapa Airport'),
#  Row(Airport_ID='6126', Name='Aleknagik / New Airport'),
#  Row(Airport_ID='6128', Name='Mercer County Airport'),
#  Row(Airport_ID='6130', Name='Mid Delta Regional Airport'),
#  Row(Airport_ID='6133', Name='Tri Cities Airport'),
#  Row(Airport_ID='6134', Name='Akutan Seaplane Base'),
#  Row(Airport_ID='6136', Name='Lopez Island Airport'),
#  Row(Airport_ID='6415', Name='Waikoloa Heliport'),
#  Row(Airport_ID='6426', Name='Worcester Regional Airport'),
#  Row(Airport_ID='6445', Name='Bremerton National Airport'),
#  Row(Airport_ID='6446', Name='Spencer Municipal Airport'),
#  Row(Airport_ID='6447', Name='Jefferson City Memorial Airport'),
#  Row(Airport_ID='6456', Name='Provincetown Municipal Airport'),
#  Row(Airport_ID='6481', Name='Fullerton Municipal Airport'),
#  Row(Airport_ID='6482', Name='Concord-Padgett Regional Airport'),
#  Row(Airport_ID='6494', Name='Friedman Memorial Airport'),
#  Row(Airport_ID='6500', Name='Mason City Municipal Airport'),
#  Row(Airport_ID='6505', Name='Phoenix-Mesa-Gateway Airport'),
#  Row(Airport_ID='6712', Name='Anaktuvuk Pass Airport'),
#  Row(Airport_ID='6713', Name='Anvik Airport'),
#  Row(Airport_ID='6714', Name='Atqasuk Edward Burnell Sr Memorial Airport'),
#  Row(Airport_ID='6715', Name='Gambell Airport'),
#  Row(Airport_ID='6716', Name='Hooper Bay Airport'),
#  Row(Airport_ID='6717', Name='Kaltag Airport'),
#  Row(Airport_ID='6718', Name="St Mary's Airport"),
#  Row(Airport_ID='6719', Name='Kivalina Airport'),
#  Row(Airport_ID='6720', Name='Mekoryuk Airport'),
#  Row(Airport_ID='6722', Name='Ruby Airport'),
#  Row(Airport_ID='6723', Name='Shishmaref Airport'),
#  Row(Airport_ID='6724', Name='Savoonga Airport'),
#  Row(Airport_ID='6725', Name='Noatak Airport'),
#  Row(Airport_ID='6729', Name='Arctic Village Airport'),
#  Row(Airport_ID='6736', Name='Port Clarence Coast Guard Station'),
#  Row(Airport_ID='6739', Name='Hagerstown Regional Richard A Henson Field'),
#  Row(Airport_ID='6742', Name='Sand Point Airport'),
#  Row(Airport_ID='6755', Name='Deering Airport'),
#  Row(Airport_ID='6763', Name='Igiugig Airport'),
#  Row(Airport_ID='6764', Name='New Stuyahok Airport'),
#  Row(Airport_ID='6765', Name='King Cove Airport'),
#  Row(Airport_ID='6766', Name='Port Heiden Airport'),
#  Row(Airport_ID='6767', Name='Togiak Airport'),
#  Row(Airport_ID='6800', Name='Delta County Airport'),
#  Row(Airport_ID='6803', Name='Yakutat Airport'),
#  Row(Airport_ID='6825', Name='Williamson County Regional Airport'),
#  Row(Airport_ID='6837', Name='Ford Airport'),
#  Row(Airport_ID='6838', Name='Marquette Airport'),
#  Row(Airport_ID='6839', Name='Allakaket Airport'),
#  Row(Airport_ID='6844', Name='Michigan City Municipal Airport'),
#  Row(Airport_ID='6845', Name='Seward Airport'),
#  Row(Airport_ID='6849', Name='Grand Marais Cook County Airport'),
#  Row(Airport_ID='6853', Name='Wausau Downtown Airport'),
#  Row(Airport_ID='6871', Name='Delaware County Johnson Field'),
#  Row(Airport_ID='6873', Name='Purdue University Airport'),
#  Row(Airport_ID='6876', Name='Brown County Airport'),
#  Row(Airport_ID='6877', Name='North Las Vegas Airport'),
#  Row(Airport_ID='6878', Name='Kenosha Regional Airport'),
#  Row(Airport_ID='6880', Name='Montrose Regional Airport'),
#  Row(Airport_ID='6881', Name='Riverton Regional Airport'),
#  Row(Airport_ID='6883', Name='Eastern Oregon Regional At Pendleton Airport'),
#  Row(Airport_ID='6909', Name='Wittman Regional Airport'),
#  Row(Airport_ID='6916', Name='Pangborn Memorial Airport'),
#  Row(Airport_ID='6948', Name='NAS Fort Worth JRB/Carswell Field'),
#  Row(Airport_ID='6956', Name='Gary Chicago International Airport'),
#  Row(Airport_ID='6957', Name='Brainerd Lakes Regional Airport'),
#  Row(Airport_ID='6958', Name='Greenbrier Valley Airport'),
#  Row(Airport_ID='6959', Name='Pitt Greenville Airport'),
#  Row(Airport_ID='6960', Name='Chefornak Airport'),
#  Row(Airport_ID='6961', Name='Oxnard Airport'),
#  Row(Airport_ID='6962', Name='Branson Airport'),
#  Row(Airport_ID='6968', Name='Schenectady County Airport'),
#  Row(Airport_ID='6989', Name='Northeast Florida Regional Airport'),
#  Row(Airport_ID='6992', Name='Charles M. Schulz Sonoma County Airport'),
#  Row(Airport_ID='6993', Name='Kissimmee Gateway Airport'),
#  Row(Airport_ID='6994', Name='Lake City Gateway Airport'),
#  Row(Airport_ID='6995', Name='Deland Municipal Sidney H Taylor Field'),
#  Row(Airport_ID='6996', Name='Haller Airpark'),
#  Row(Airport_ID='6998', Name='Logan-Cache Airport'),
#  Row(Airport_ID='6999', Name='Brigham City Regional Airport'),
#  Row(Airport_ID='7000', Name='Malad City Airport'),
#  Row(Airport_ID='7001', Name='Aspen-Pitkin Co/Sardy Field'),
#  Row(Airport_ID='7009', Name='Kerrville Municipal Louis Schreiner Field'),
#  Row(Airport_ID='7011', Name='Sussex County Airport'),
#  Row(Airport_ID='7013', Name='Great Bend Municipal Airport'),
#  Row(Airport_ID='7014', Name='Hays Regional Airport'),
#  Row(Airport_ID='7015', Name='Spirit of St Louis Airport'),
#  Row(Airport_ID='7016', Name='Ely Municipal Airport'),
#  Row(Airport_ID='7017', Name='Grand Rapids Itasca Co-Gordon Newstrom field'),
#  Row(Airport_ID='7018', Name='Thief River Falls Regional Airport'),
#  Row(Airport_ID='7019', Name='Eagle River Union Airport'),
#  Row(Airport_ID='7020', Name='Lakeland-Noble F. Lee Memorial field'),
#  Row(Airport_ID='7021', Name='Ankeny Regional Airport'),
#  Row(Airport_ID='7023', Name='Corpus Christi Naval Air Station/Truax Field'),
#  Row(Airport_ID='7025', Name='Catalina Airport'),
#  Row(Airport_ID='7026', Name='Mojave Airport'),
#  Row(Airport_ID='7035', Name='Hutchinson Municipal Airport'),
#  Row(Airport_ID='7042', Name='Rosecrans Memorial Airport'),
#  Row(Airport_ID='7048', Name='Volk Field'),
#  Row(Airport_ID='7051', Name='Gunnison Crested Butte Regional Airport'),
#  Row(Airport_ID='7053', Name='Zamperini Field'),
#  Row(Airport_ID='7054', Name='Manistee Co Blacker Airport'),
#  Row(Airport_ID='7056', Name='Charlotte County Airport'),
#  Row(Airport_ID='7058', Name='Northern Aroostook Regional Airport'),
#  Row(Airport_ID='7059', Name='Chautauqua County-Jamestown Airport'),
#  Row(Airport_ID='7061', Name='Lake Cumberland Regional Airport'),
#  Row(Airport_ID='7062', Name='Shenandoah Valley Regional Airport'),
#  Row(Airport_ID='7063', Name='Devils Lake Regional Airport'),
#  Row(Airport_ID='7064', Name='Dickinson Theodore Roosevelt Regional Airport'),
#  Row(Airport_ID='7065', Name='Sidney - Richland Regional Airport'),
#  Row(Airport_ID='7066', Name='Chadron Municipal Airport'),
#  Row(Airport_ID='7067', Name='Alliance Municipal Airport'),
#  Row(Airport_ID='7068', Name='Mc Cook Ben Nelson Regional Airport'),
#  Row(Airport_ID='7069', Name='The Florida Keys Marathon Airport'),
#  Row(Airport_ID='7070', Name='Dawson Community Airport'),
#  Row(Airport_ID='7071', Name='L M Clayton Airport'),
#  Row(Airport_ID='7072', Name='Yellowstone Airport'),
#  Row(Airport_ID='7073', Name='San Luis Valley Regional Bergman Field'),
#  Row(Airport_ID='7074', Name='Canyonlands Field'),
#  Row(Airport_ID='7075', Name='Ely Airport Yelland Field'),
#  Row(Airport_ID='7076', Name='Vernal Regional Airport'),
#  Row(Airport_ID='7077', Name='Sierra Blanca Regional Airport'),
#  Row(Airport_ID='7078', Name='Show Low Regional Airport'),
#  Row(Airport_ID='7079', Name='McCall Municipal Airport'),
#  Row(Airport_ID='7080', Name='Lemhi County Airport'),
#  Row(Airport_ID='7081', Name='Mammoth Yosemite Airport'),
#  Row(Airport_ID='7082', Name='Friday Harbor Airport'),
#  Row(Airport_ID='7083', Name='Orcas Island Airport'),
#  Row(Airport_ID='7085', Name='Astoria Regional Airport'),
#  Row(Airport_ID='7086', Name='Newport Municipal Airport'),
#  Row(Airport_ID='7087', Name='Emmonak Airport'),
#  Row(Airport_ID='7088', Name='Unalakleet Airport'),
#  Row(Airport_ID='7089', Name='Ugnu-Kuparuk Airport'),
#  Row(Airport_ID='7090', Name='Shageluk Airport'),
#  Row(Airport_ID='7091', Name='Chuathbaluk Airport'),
#  Row(Airport_ID='7092', Name='Nuiqsut Airport'),
#  Row(Airport_ID='7093', Name='Eek Airport'),
#  Row(Airport_ID='7094', Name='Kasigluk Airport'),
#  Row(Airport_ID='7095', Name='Kwethluk Airport'),
#  Row(Airport_ID='7096', Name='Kwigillingok Airport'),
#  Row(Airport_ID='7097', Name='Marshall Don Hunter Sr Airport'),
#  Row(Airport_ID='7098', Name='Russian Mission Airport'),
#  Row(Airport_ID='7101', Name='Koliganek Airport'),
#  Row(Airport_ID='7103', Name='Manokotak Airport'),
#  Row(Airport_ID='7105', Name='Chalkyitsik Airport'),
#  Row(Airport_ID='7106', Name='Eagle Airport'),
#  Row(Airport_ID='7107', Name='Hughes Airport'),
#  Row(Airport_ID='7108', Name='Huslia Airport'),
#  Row(Airport_ID='7111', Name='Nulato Airport'),
#  Row(Airport_ID='7114', Name='Venetie Airport'),
#  Row(Airport_ID='7115', Name='Beaver Airport'),
#  Row(Airport_ID='7116', Name='Central Airport'),
#  Row(Airport_ID='7117', Name='Shungnak Airport'),
#  Row(Airport_ID='7120', Name='Inyokern Airport'),
#  Row(Airport_ID='7121', Name='Visalia Municipal Airport'),
#  Row(Airport_ID='7122', Name='Merced Regional Macready Field'),
#  Row(Airport_ID='7126', Name='Phoenix Goodyear Airport'),
#  Row(Airport_ID='7135', Name='Angoon Seaplane Base'),
#  Row(Airport_ID='7136', Name='Elfin Cove Seaplane Base'),
#  Row(Airport_ID='7140', Name='Funter Bay Seaplane Base'),
#  Row(Airport_ID='7142', Name='Hoonah Airport'),
#  Row(Airport_ID='7143', Name='Kake Airport'),
#  Row(Airport_ID='7146', Name='Metlakatla Seaplane Base'),
#  Row(Airport_ID='7148', Name='Hydaburg Seaplane Base'),
#  Row(Airport_ID='7154', Name='Egegik Airport'),
#  Row(Airport_ID='7157', Name='Perryville Airport'),
#  Row(Airport_ID='7158', Name='Pilot Point Airport'),
#  Row(Airport_ID='7159', Name='South Naknek Nr 2 Airport'),
#  Row(Airport_ID='7160', Name='Akhiok Airport'),
#  Row(Airport_ID='7161', Name='Karluk Airport'),
#  Row(Airport_ID='7162', Name='Larsen Bay Airport'),
#  Row(Airport_ID='7177', Name='Ambler Airport'),
#  Row(Airport_ID='7178', Name='Buckland Airport'),
#  Row(Airport_ID='7179', Name='Bob Baker Memorial Airport'),
#  Row(Airport_ID='7180', Name='Kobuk Airport'),
#  Row(Airport_ID='7181', Name='Robert (Bob) Curtis Memorial Airport'),
#  Row(Airport_ID='7182', Name='Selawik Airport'),
#  Row(Airport_ID='7183', Name='Brevig Mission Airport'),
#  Row(Airport_ID='7184', Name='Elim Airport'),
#  Row(Airport_ID='7185', Name='Golovin Airport'),
#  Row(Airport_ID='7186', Name='Teller Airport'),
#  Row(Airport_ID='7187', Name='Wales Airport'),
#  Row(Airport_ID='7188', Name='White Mountain Airport'),
#  Row(Airport_ID='7190', Name='Koyuk Alfred Adams Airport'),
#  Row(Airport_ID='7191', Name='St Michael Airport'),
#  Row(Airport_ID='7192', Name='Shaktoolik Airport'),
#  Row(Airport_ID='7194', Name='Tin City Long Range Radar Station Airport'),
#  Row(Airport_ID='7195', Name='Atka Airport'),
#  Row(Airport_ID='7196', Name='Nikolski Air Station'),
#  Row(Airport_ID='7198', Name='Yakataga Airport'),
#  Row(Airport_ID='7199', Name='Alakanuk Airport'),
#  Row(Airport_ID='7201', Name='Kipnuk Airport'),
#  Row(Airport_ID='7202', Name='False Pass Airport'),
#  Row(Airport_ID='7203', Name='Nelson Lagoon Airport'),
#  Row(Airport_ID='7204', Name='Port Moller Airport'),
#  Row(Airport_ID='7205', Name='Klawock Airport'),
#  Row(Airport_ID='7206', Name='Quinhagak Airport'),
#  Row(Airport_ID='7207', Name='Kotlik Airport'),
#  Row(Airport_ID='7208', Name='Koyukuk Airport'),
#  Row(Airport_ID='7209', Name='Scammon Bay Airport'),
#  Row(Airport_ID='7210', Name='Nondalton Airport'),
#  Row(Airport_ID='7213', Name='Kongiganak Airport'),
#  Row(Airport_ID='7214', Name='Nikolai Airport'),
#  Row(Airport_ID='7217', Name='Akiak Airport'),
#  Row(Airport_ID='7220', Name='Wainwright Airport'),
#  Row(Airport_ID='7233', Name='Chenega Bay Airport'),
#  Row(Airport_ID='7235', Name='Tok Junction Airport'),
#  Row(Airport_ID='7236', Name='Circle City /New/ Airport'),
#  Row(Airport_ID='7240', Name='Sleetmute Airport'),
#  Row(Airport_ID='7242', Name='Healy River Airport'),
#  Row(Airport_ID='7244', Name='Klawock Seaplane Base'),
#  Row(Airport_ID='7245', Name='Minchumina Airport'),
#  Row(Airport_ID='7246', Name='Manley Hot Springs Airport'),
#  Row(Airport_ID='7415', Name='Eastern WV Regional Airport/Shepherd Field'),
#  Row(Airport_ID='7494', Name='Rock Hill - York County Airport'),
#  Row(Airport_ID='7495', Name='Allegheny County Airport'),
#  Row(Airport_ID='7496', Name='Cecil Airport'),
#  Row(Airport_ID='7497', Name='Fulton County Airport Brown Field'),
#  Row(Airport_ID='7511', Name='The Ohio State University Airport - Don Scott Field'),
#  Row(Airport_ID='7513', Name='Addison Airport'),
#  Row(Airport_ID='7514', Name='Destin Executive Airport'),
#  Row(Airport_ID='7522', Name='Kinston Regional Jetport At Stallings Field'),
#  Row(Airport_ID='7523', Name='First Flight Airport'),
#  Row(Airport_ID='7579', Name='Provo Municipal Airport'),
#  Row(Airport_ID='7580', Name='Steamboat Springs Bob Adams Field'),
#  Row(Airport_ID='7581', Name='Delta Municipal Airport'),
#  Row(Airport_ID='7582', Name='Richfield Municipal Airport'),
#  Row(Airport_ID='7583', Name='Carbon County Regional/Buck Davis Field'),
#  Row(Airport_ID='7584', Name='Los Alamos Airport'),
#  Row(Airport_ID='7586', Name='Lake Havasu City Airport'),
#  Row(Airport_ID='7587', Name='Winslow Lindbergh Regional Airport'),
#  Row(Airport_ID='7588', Name='Douglas Municipal Airport'),
#  Row(Airport_ID='7621', Name='Bartow Municipal Airport'),
#  Row(Airport_ID='7629', Name='Livermore Municipal Airport'),
#  Row(Airport_ID='7630', Name='Mariposa Yosemite Airport'),
#  Row(Airport_ID='7646', Name='Jacqueline Cochran Regional Airport'),
#  Row(Airport_ID='7647', Name='Santa Monica Municipal Airport'),
#  Row(Airport_ID='7648', Name='Bermuda Dunes Airport'),
#  Row(Airport_ID='7649', Name='Scottsdale Airport'),
#  Row(Airport_ID='7650', Name='Olympia Regional Airport'),
#  Row(Airport_ID='7651', Name='Yolo County Davis Woodland Winters Airport'),
#  Row(Airport_ID='7652', Name='Garfield County Regional Airport'),
#  Row(Airport_ID='7653', Name='Shively Field'),
#  Row(Airport_ID='7654', Name='DeKalb Peachtree Airport'),
#  Row(Airport_ID='7655', Name='Monroe County Airport'),
#  Row(Airport_ID='7656', Name='Witham Field'),
#  Row(Airport_ID='7657', Name='Morristown Municipal Airport'),
#  Row(Airport_ID='7658', Name='Napa County Airport'),
#  Row(Airport_ID='7659', Name='Brown Field Municipal Airport'),
#  Row(Airport_ID='7662', Name='Venice Municipal Airport'),
#  Row(Airport_ID='7663', Name='Palm Beach County Glades Airport'),
#  Row(Airport_ID='7669', Name='Northwest Florida Beaches International Airport'),
#  Row(Airport_ID='7670', Name='San Bernardino International Airport'),
#  Row(Airport_ID='7683', Name='San Carlos Airport'),
#  Row(Airport_ID='7690', Name='Rocky Mount Wilson Regional Airport'),
#  Row(Airport_ID='7691', Name='Whittier Airport'),
#  Row(Airport_ID='7692', Name='Soldotna Airport'),
#  Row(Airport_ID='7693', Name='Gillespie Field'),
#  Row(Airport_ID='7694', Name='San Clemente Island Naval Auxiliary Landing Field'),
#  Row(Airport_ID='7702', Name='Truckee Tahoe Airport'),
#  Row(Airport_ID='7712', Name='Cobb County-Mc Collum Field'),
#  Row(Airport_ID='7716', Name='Dell Flight Strip'),
#  Row(Airport_ID='7717', Name='Mission Field'),
#  Row(Airport_ID='7720', Name='Big Timber Airport'),
#  Row(Airport_ID='7721', Name='Tulip City Airport'),
#  Row(Airport_ID='7727', Name='Monument Valley Airport'),
#  Row(Airport_ID='7729', Name='West 30th St. Heliport'),
#  Row(Airport_ID='7732', Name='Lakeland Linder International Airport'),
#  Row(Airport_ID='7767', Name='Indianola Municipal Airport'),
#  Row(Airport_ID='7769', Name='French Valley Airport'),
#  Row(Airport_ID='7775', Name='Carl R Keller Field'),
#  Row(Airport_ID='7776', Name='Dayton-Wright Brothers Airport'),
#  Row(Airport_ID='7777', Name='Richmond Municipal Airport'),
#  Row(Airport_ID='7778', Name='Findlay Airport'),
#  Row(Airport_ID='7809', Name='Black Hills Airport-Clyde Ice Field'),
#  Row(Airport_ID='7817', Name='Olive Branch Airport'),
#  Row(Airport_ID='7822', Name='Rocky Mountain Metropolitan Airport'),
#  Row(Airport_ID='7826', Name='Salem Municipal Airport/McNary Field'),
#  Row(Airport_ID='7827', Name='Tunica Municipal Airport'),
#  Row(Airport_ID='7839', Name='Lawrence J Timmerman Airport'),
#  Row(Airport_ID='7840', Name='Southern Wisconsin Regional Airport'),
#  Row(Airport_ID='7846', Name='Arlington Municipal Airport'),
#  Row(Airport_ID='7847', Name='Gwinnett County Briscoe Field'),
#  Row(Airport_ID='7848', Name='Bowling Green Warren County Regional Airport'),
#  Row(Airport_ID='7849', Name='Richard Lloyd Jones Jr Airport'),
#  Row(Airport_ID='7857', Name='Bryce Canyon Airport'),
#  Row(Airport_ID='7859', Name='Burlington Alamance Regional Airport'),
#  Row(Airport_ID='7869', Name='New Century Aircenter Airport'),
#  Row(Airport_ID='7870', Name='Easton Newnam Field'),
#  Row(Airport_ID='7875', Name='Yuba County Airport'),
#  Row(Airport_ID='7880', Name='Halliburton Field'),
#  Row(Airport_ID='7885', Name='Garner Field'),
#  Row(Airport_ID='7886', Name='Lewis University Airport'),
#  Row(Airport_ID='7888', Name='Buchanan Field'),
#  Row(Airport_ID='7889', Name='Ocean Reef Club Airport'),
#  Row(Airport_ID='7907', Name='Ohio University Snyder Field'),
#  Row(Airport_ID='7908', Name='Springfield-Beckley Municipal Airport'),
#  Row(Airport_ID='7925', Name='Philip Billard Municipal Airport'),
#  Row(Airport_ID='7928', Name='Benson Airstrip'),
#  Row(Airport_ID='7929', Name='Rough River State Park Airport'),
#  Row(Airport_ID='7930', Name='Smyrna Airport'),
#  Row(Airport_ID='7931', Name='Franklin County Airport'),
#  Row(Airport_ID='7935', Name='Collin County Regional At Mc Kinney Airport'),
#  Row(Airport_ID='7936', Name='Chicago Executive Airport'),
#  Row(Airport_ID='7938', Name='Southwest Washington Regional Airport'),
#  Row(Airport_ID='7978', Name='Wilmington Airpark'),
#  Row(Airport_ID='7979', Name='Marana Regional Airport'),
#  Row(Airport_ID='7980', Name='Casa Grande Municipal Airport'),
#  Row(Airport_ID='7981', Name='Mobile Airport'),
#  Row(Airport_ID='7982', Name='Buckeye Municipal Airport'),
#  Row(Airport_ID='7983', Name='Gila Bend Municipal Airport'),
#  Row(Airport_ID='7984', Name='McMinn County Airport'),
#  Row(Airport_ID='7985', Name='Sterling Municipal Airport'),
#  Row(Airport_ID='7986', Name='Rawlins Municipal Airport/Harvey Field'),
#  Row(Airport_ID='7990', Name='Essex County Airport'),
#  Row(Airport_ID='7991', Name='Lee C Fine Memorial Airport'),
#  Row(Airport_ID='7998', Name='Thomasville Regional Airport'),
#  Row(Airport_ID='7999', Name='Henderson Executive Airport'),
#  ...]

# %%
querier.get_airlines_with_code_share()
# Out:
# [Row(Airline='CI'),
#  Row(Airline='AZ'),
#  Row(Airline='SC'),
#  Row(Airline='UA'),
#  Row(Airline='RO'),
#  Row(Airline='LA'),
#  Row(Airline='XL'),
#  Row(Airline='AM'),
#  Row(Airline='PS'),
#  Row(Airline='AA'),
#  Row(Airline='MK'),
#  Row(Airline='AY'),
#  Row(Airline='IB'),
#  Row(Airline='DC'),
#  Row(Airline='NX'),
#  Row(Airline='T3'),
#  Row(Airline='AT'),
#  Row(Airline='UL'),
#  Row(Airline='AV'),
#  Row(Airline='S7'),
#  Row(Airline='HY'),
#  Row(Airline='JJ'),
#  Row(Airline='QF'),
#  Row(Airline='AD'),
#  Row(Airline='NT'),
#  Row(Airline='SV'),
#  Row(Airline='CZ'),
#  Row(Airline='VA'),
#  Row(Airline='B2'),
#  Row(Airline='PG'),
#  Row(Airline='CX'),
#  Row(Airline='S4'),
#  Row(Airline='WY'),
#  Row(Airline='NH'),
#  Row(Airline='KL'),
#  Row(Airline='LR'),
#  Row(Airline='W2'),
#  Row(Airline='OA'),
#  Row(Airline='XY'),
#  Row(Airline='SU'),
#  Row(Airline='LX'),
#  Row(Airline='F7'),
#  Row(Airline='TP'),
#  Row(Airline='7H'),
#  Row(Airline='GZ'),
#  Row(Airline='SA'),
#  Row(Airline='CA'),
#  Row(Airline='DL'),
#  Row(Airline='BR'),
#  Row(Airline='Z6'),
#  Row(Airline='LW'),
#  Row(Airline='9K'),
#  Row(Airline='MD'),
#  Row(Airline='DE'),
#  Row(Airline='MO'),
#  Row(Airline='F9'),
#  Row(Airline='9W'),
#  Row(Airline='J2'),
#  Row(Airline='ME'),
#  Row(Airline='AI'),
#  Row(Airline='WB'),
#  Row(Airline='B7'),
#  Row(Airline='DY'),
#  Row(Airline='YO'),
#  Row(Airline='KC'),
#  Row(Airline='7F'),
#  Row(Airline='US'),
#  Row(Airline='ZH'),
#  Row(Airline='LH'),
#  Row(Airline='TS'),
#  Row(Airline='EK'),
#  Row(Airline='MS'),
#  Row(Airline='4M'),
#  Row(Airline='AE'),
#  Row(Airline='CM'),
#  Row(Airline='MJ'),
#  Row(Airline='TG'),
#  Row(Airline='GF'),
#  Row(Airline='KQ'),
#  Row(Airline='2P'),
#  Row(Airline='TN'),
#  Row(Airline='IY'),
#  Row(Airline='VS'),
#  Row(Airline='TD'),
#  Row(Airline='UX'),
#  Row(Airline='EY'),
#  Row(Airline='HA'),
#  Row(Airline='BA'),
#  Row(Airline='M5'),
#  Row(Airline='ET'),
#  Row(Airline='JL'),
#  Row(Airline='EI'),
#  Row(Airline='JT'),
#  Row(Airline='CU'),
#  Row(Airline='FJ'),
#  Row(Airline='WS'),
#  Row(Airline='GE'),
#  Row(Airline='SK'),
#  Row(Airline='AB'),
#  Row(Airline='P1'),
#  Row(Airline='QV'),
#  Row(Airline='FM'),
#  Row(Airline='LO'),
#  Row(Airline='MH'),
#  Row(Airline='MU'),
#  Row(Airline='OS'),
#  Row(Airline='LG'),
#  Row(Airline='UN'),
#  Row(Airline='KM'),
#  Row(Airline='KA'),
#  Row(Airline='SN'),
#  Row(Airline='TX'),
#  Row(Airline='NZ'),
#  Row(Airline='BT'),
#  Row(Airline='HU'),
#  Row(Airline='QR'),
#  Row(Airline='KE'),
#  Row(Airline='OZ'),
#  Row(Airline='CY'),
#  Row(Airline='IG'),
#  Row(Airline='S2'),
#  Row(Airline='W3'),
#  Row(Airline='GA'),
#  Row(Airline='RJ'),
#  Row(Airline='AS'),
#  Row(Airline='BE'),
#  Row(Airline='AC'),
#  Row(Airline='5T'),
#  Row(Airline='FL'),
#  Row(Airline='I9'),
#  Row(Airline='SS'),
#  Row(Airline='TF'),
#  Row(Airline='AR'),
#  Row(Airline='OK'),
#  Row(Airline='PR'),
#  Row(Airline='TK'),
#  Row(Airline='AP'),
#  Row(Airline='NF'),
#  Row(Airline='A3'),
#  Row(Airline='HM'),
#  Row(Airline='TA'),
#  Row(Airline='VN'),
#  Row(Airline='AF'),
#  Row(Airline='SQ'),
#  Row(Airline='WN'),
#  Row(Airline='OU'),
#  Row(Airline='5N')]

# %%
querier.get_active_airlines_in_United_States()
# Out:
# [Row(Airline_ID='10', Name='40-Mile Air'),
#  Row(Airline_ID='22', Name='Aloha Airlines'),
#  Row(Airline_ID='24', Name='American Airlines'),
#  Row(Airline_ID='35', Name='Allegiant Air'),
#  Row(Airline_ID='109', Name='Alaska Central Express'),
#  Row(Airline_ID='149', Name='Air Cargo Carriers'),
#  Row(Airline_ID='210', Name='Airlift International'),
#  Row(Airline_ID='281', Name='America West Airlines'),
#  Row(Airline_ID='282', Name='Air Wisconsin'),
#  Row(Airline_ID='287', Name='Allegheny Commuter Airlines'),
#  Row(Airline_ID='295', Name='Air Sunshine'),
#  Row(Airline_ID='315', Name='ATA Airlines'),
#  Row(Airline_ID='397', Name='Arrow Air'),
#  Row(Airline_ID='452', Name='Atlantic Southeast Airlines'),
#  Row(Airline_ID='659', Name='American Eagle Airlines'),
#  Row(Airline_ID='792', Name='Access Air'),
#  Row(Airline_ID='882', Name='Air Florida'),
#  Row(Airline_ID='928', Name='Atlas Air'),
#  Row(Airline_ID='1316', Name='AirTran Airways'),
#  Row(Airline_ID='1442', Name='Bemidji Airlines'),
#  Row(Airline_ID='1472', Name='Bering Air'),
#  Row(Airline_ID='1629', Name='Cape Air'),
#  Row(Airline_ID='1739', Name='Chautauqua Airlines'),
#  Row(Airline_ID='1814', Name='Coastal Air'),
#  Row(Airline_ID='1821', Name='Colgan Air'),
#  Row(Airline_ID='1828', Name='Comair'),
#  Row(Airline_ID='1843', Name='CommutAir'),
#  Row(Airline_ID='1860', Name='Compass Airlines'),
#  Row(Airline_ID='1881', Name='Continental Airlines'),
#  Row(Airline_ID='1883', Name='Continental Express'),
#  Row(Airline_ID='1884', Name='Continental Micronesia'),
#  Row(Airline_ID='1931', Name='Crown Airways'),
#  Row(Airline_ID='2009', Name='Delta Air Lines'),
#  Row(Airline_ID='2261', Name='Evergreen International Airlines'),
#  Row(Airline_ID='2293', Name='Express One International'),
#  Row(Airline_ID='2295', Name='ExpressJet'),
#  Row(Airline_ID='2404', Name='Florida West International Airways'),
#  Row(Airline_ID='2454', Name='Freedom Air'),
#  Row(Airline_ID='2456', Name='Freedom Airlines'),
#  Row(Airline_ID='2468', Name='Frontier Airlines'),
#  Row(Airline_ID='2470', Name='Frontier Flying Service'),
#  Row(Airline_ID='2577', Name='GoJet Airlines'),
#  Row(Airline_ID='2607', Name='Great Lakes Airlines'),
#  Row(Airline_ID='2645', Name='Gulfstream International Airlines'),
#  Row(Airline_ID='2657', Name='Hageland Aviation Services'),
#  Row(Airline_ID='2688', Name='Hawaiian Airlines'),
#  Row(Airline_ID='2778', Name='Horizon Air'),
#  Row(Airline_ID='2855', Name='Indigo'),
#  Row(Airline_ID='2937', Name='Island Airlines'),
#  Row(Airline_ID='3001', Name='Jet Airways'),
#  Row(Airline_ID='3029', Name='JetBlue Airways'),
#  Row(Airline_ID='3123', Name='Kenmore Air'),
#  Row(Airline_ID='3466', Name='Mesa Airlines'),
#  Row(Airline_ID='3467', Name='Mesaba Airlines'),
#  Row(Airline_ID='3494', Name='Midway Airlines'),
#  Row(Airline_ID='3497', Name='Midwest Airlines'),
#  Row(Airline_ID='3641', Name='NetJets'),
#  Row(Airline_ID='3644', Name='New England Airlines'),
#  Row(Airline_ID='3731', Name='Northwest Airlines'),
#  Row(Airline_ID='3781', Name='Omni Air International'),
#  Row(Airline_ID='3860', Name='Pacific Island Aviation'),
#  Row(Airline_ID='3865', Name='Pacific Wings'),
#  Row(Airline_ID='3935', Name='Peninsula Airways'),
#  Row(Airline_ID='3969', Name='Piedmont Airlines (1948-1989)'),
#  Row(Airline_ID='3976', Name='Pinnacle Airlines'),
#  Row(Airline_ID='4026', Name='Potomac Air'),
#  Row(Airline_ID='4187', Name='Republic Airlines'),
#  Row(Airline_ID='4294', Name='Ryan Air Services'),
#  Row(Airline_ID='4295', Name='Ryan International Airlines'),
#  Row(Airline_ID='4335', Name='Seaborne Airlines'),
#  Row(Airline_ID='4342', Name='Scenic Airlines'),
#  Row(Airline_ID='4356', Name='Sun Country Airlines'),
#  Row(Airline_ID='4370', Name='Southeast Air'),
#  Row(Airline_ID='4411', Name='Skagway Air Service'),
#  Row(Airline_ID='4547', Name='Southwest Airlines'),
#  Row(Airline_ID='4589', Name='Skywalk Airlines'),
#  Row(Airline_ID='4687', Name='Spirit Airlines'),
#  Row(Airline_ID='4738', Name='SkyWest'),
#  Row(Airline_ID='4804', Name='Southern Airways'),
#  Row(Airline_ID='4816', Name='South Pacific Island Airways'),
#  Row(Airline_ID='4822', Name='Shuttle America'),
#  Row(Airline_ID='5160', Name='Trans States Airlines'),
#  Row(Airline_ID='5207', Name='USA3000 Airlines'),
#  Row(Airline_ID='5209', Name='United Airlines'),
#  Row(Airline_ID='5265', Name='US Airways'),
#  Row(Airline_ID='5268', Name='US Helicopter'),
#  Row(Airline_ID='5279', Name='United States Air Force'),
#  Row(Airline_ID='5284', Name='US Helicopter Corporation'),
#  Row(Airline_ID='5331', Name='Virgin America'),
#  Row(Airline_ID='5424', Name='Western Airlines'),
#  Row(Airline_ID='5465', Name='World Airways'),
#  Row(Airline_ID='8461', Name='Carnival Air Lines'),
#  Row(Airline_ID='8809', Name='Island Air (WP)'),
#  Row(Airline_ID='9833', Name='Epic Holiday'),
#  Row(Airline_ID='10123', Name='Texas Wings'),
#  Row(Airline_ID='10226', Name='Atifly'),
#  Row(Airline_ID='10739', Name='Air Choice One'),
#  Row(Airline_ID='10748', Name='Locair'),
#  Row(Airline_ID='10765', Name='SeaPort Airlines'),
#  Row(Airline_ID='10776', Name='Salmon Air'),
#  Row(Airline_ID='10912', Name='Alaska Seaplane Service'),
#  Row(Airline_ID='12961', Name='Gryphon Airlines'),
#  Row(Airline_ID='13391', Name='U.S. Air'),
#  Row(Airline_ID='13633', Name='PanAm World Airways'),
#  Row(Airline_ID='15887', Name='CBM America'),
#  Row(Airline_ID='15975', Name='Black Stallion Airways'),
#  Row(Airline_ID='16135', Name='Yellowstone Club Private Shuttle'),
#  Row(Airline_ID='16264', Name='Trans Pas Air'),
#  Row(Airline_ID='16625', Name='Papillon Grand Canyon Helicopters'),
#  Row(Airline_ID='16702', Name='Usa Sky Cargo'),
#  Row(Airline_ID='16726', Name='Era Alaska'),
#  Row(Airline_ID='16735', Name='Hankook Air US'),
#  Row(Airline_ID='16932', Name='Orbit Airlines'),
#  Row(Airline_ID='17519', Name='SENIC AIRLINES'),
#  Row(Airline_ID='17563', Name='XOJET'),
#  Row(Airline_ID='17628', Name='Orbit International Airlines'),
#  Row(Airline_ID='17629', Name='Orbit Regional Airlines'),
#  Row(Airline_ID='17630', Name='Orbit Atlantic Airways'),
#  Row(Airline_ID='17841', Name='Aws express'),
#  Row(Airline_ID='17859', Name='Southjet'),
#  Row(Airline_ID='17860', Name='Southjet connect'),
#  Row(Airline_ID='17862', Name='Southjet cargo'),
#  Row(Airline_ID='18169', Name='Patriot Airways'),
#  Row(Airline_ID='18178', Name='Vision Airlines (V2)'),
#  Row(Airline_ID='18239', Name='Yellowtail'),
#  Row(Airline_ID='18241', Name='Royal Airways'),
#  Row(Airline_ID='18257', Name='Executive AirShare'),
#  Row(Airline_ID='18529', Name='T.J. Air'),
#  Row(Airline_ID='18930', Name='Maryland Air'),
#  Row(Airline_ID='19016', Name='Apache Air'),
#  Row(Airline_ID='19287', Name='National Air Cargo'),
#  Row(Airline_ID='19290', Name='Eastern Atlantic Virtual Airlines'),
#  Row(Airline_ID='19350', Name='Comfort Express Virtual Charters Albany'),
#  Row(Airline_ID='19351', Name='Comfort Express Virtual Charters'),
#  Row(Airline_ID='19433', Name='XAIR USA'),
#  Row(Airline_ID='19619', Name='Envoy Air'),
#  Row(Airline_ID='19674', Name='Rainbow Air (RAI)'),
#  Row(Airline_ID='19676', Name='Rainbow Air Polynesia'),
#  Row(Airline_ID='19678', Name='Rainbow Air US'),
#  Row(Airline_ID='19774', Name='Spike Airlines'),
#  Row(Airline_ID='19804', Name='All America'),
#  Row(Airline_ID='19890', Name='Dense Airways'),
#  Row(Airline_ID='19891', Name='Dense Connection'),
#  Row(Airline_ID='19917', Name='Jet Suite'),
#  Row(Airline_ID='20060', Name='San Dima Air'),
#  Row(Airline_ID='20222', Name='OneJet'),
#  Row(Airline_ID='20565', Name='Boutique Air (Priv)'),
#  Row(Airline_ID='20607', Name='Liberty Airways'),
#  Row(Airline_ID='20710', Name='Silver Airways (3M)'),
#  Row(Airline_ID='20808', Name='Alghanim'),
#  Row(Airline_ID='20931', Name='Southern Airways Express'),
#  Row(Airline_ID='20976', Name='World Scale Airlines'),
#  Row(Airline_ID='20978', Name='All America US'),
#  Row(Airline_ID='20991', Name='Choice Airways'),
#  Row(Airline_ID='20996', Name='Dynamic Airways'),
#  Row(Airline_ID='21124', Name='ViaAir')]

# %%
querier.get_country_or_teritory_with_most_airports()
# Out:
# [Row(number=1099, Country='United States')]

# %%
querier.get_top_k_cities_with_most_incoming_airlines(10)
# Out:
# [Row(number=1224, city='London'),
#  Row(number=911, city='Atlanta'),
#  Row(number=720, city='Paris'),
#  Row(number=682, city='Chicago'),
#  Row(number=620, city='Shanghai'),
#  Row(number=614, city='Beijing'),
#  Row(number=613, city='New York'),
#  Row(number=608, city='Moscow'),
#  Row(number=506, city='Istanbul'),
#  Row(number=498, city='Los Angeles')]

# %%
querier.get_closest_airport_to_city(city="Phoenix")
# Out:
# [Row(dist=40.13331360830392, Airport_Name='South Pole Station Airport', Airport_ID='2033')]

# %%
querier.get_airport_in_each_state()
# Out:
# [Row(_contains=True, Airport_name='Mobile Downtown Airport', Airport_ID='3452', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Redstone Army Air Field', Airport_ID='3480', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Anniston Regional Airport', Airport_ID='3485', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Maxwell Air Force Base', Airport_ID='3500', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Lawson Army Air Field (Fort Benning)', Airport_ID='3539', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Dothan Regional Airport', Airport_ID='3739', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Mobile Regional Airport', Airport_ID='3782', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Birmingham-Shuttlesworth International Airport', Airport_ID='3811', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Craig Field', Airport_ID='3874', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Huntsville International Carl T Jones Field', Airport_ID='4113', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Montgomery Regional (Dannelly Field) Airport', Airport_ID='4115', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Tuscaloosa Regional Airport', Airport_ID='4387', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Northwest Alabama Regional Airport', Airport_ID='5756', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Centre-Piedmont-Cherokee County Regional Airport', Airport_ID='8293', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Northeast Alabama Regional Airport', Airport_ID='8295', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Shelby County Airport', Airport_ID='8394', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Jack Edwards Airport', Airport_ID='8460', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Madison County Executive Airport-Tom Sharp Jr Field', Airport_ID='8834', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Weedon Field', Airport_ID='9415', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Auburn University Regional Airport', Airport_ID='9418', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Bessemer Airport', Airport_ID='9428', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Talladega Municipal Airport', Airport_ID='11004', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Troy Municipal Airport at N Kenneth Campbell Field', Airport_ID='11010', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Merkel Field Sylacauga Municipal Airport', Airport_ID='11011', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Enterprise Municipal Airport', Airport_ID='11012', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Thomas C Russell Field', Airport_ID='11022', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Cairns AAF (Fort Rucker) Air Field', Airport_ID='11849', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Evergreen Regional Airport/Middleton Field', Airport_ID='12673', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Pryor Field Regional Airport', Airport_ID='12675', state_name='Alabama'),
#  Row(_contains=True, Airport_name='Barter Island LRRS Airport', Airport_ID='3411', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Wainwright Air Station', Airport_ID='3412', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Cape Lisburne LRRS Airport', Airport_ID='3413', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Point Lay LRRS Airport', Airport_ID='3414', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Bettles Airport', Airport_ID='3417', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Clear Airport', Airport_ID='3418', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Indian Mountain LRRS Airport', Airport_ID='3419', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Fort Yukon Airport', Airport_ID='3420', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Sparrevohn LRRS Airport', Airport_ID='3421', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Bryant Army Heliport', Airport_ID='3422', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Tatalina LRRS Airport', Airport_ID='3423', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Cape Romanzof LRRS Airport', Airport_ID='3424', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Cape Newenham LRRS Airport', Airport_ID='3427', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Iliamna Airport', Airport_ID='3429', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Platinum Airport', Airport_ID='3430', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Big Mountain Airport', Airport_ID='3431', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Merrill Field', Airport_ID='3438', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Dillingham Airport', Airport_ID='3460', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Allen Army Airfield', Airport_ID='3475', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Annette Island Airport', Airport_ID='3477', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Juneau International Airport', Airport_ID='3492', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kodiak Airport', Airport_ID='3531', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Northway Airport', Airport_ID='3568', state_name='Alaska'),
#  Row(_contains=True, Airport_name='"Warren ""Bud"" Woods Palmer Municipal Airport"', Airport_ID='3569', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Wiley Post Will Rogers Memorial Airport', Airport_ID='3571', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Bethel Airport', Airport_ID='3599', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Merle K (Mudhole) Smith Airport', Airport_ID='3610', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nome Airport', Airport_ID='3615', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Deadhorse Airport', Airport_ID='3620', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kenai Municipal Airport', Airport_ID='3628', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Eielson Air Force Base', Airport_ID='3649', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Homer Airport', Airport_ID='3664', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Elmendorf Air Force Base', Airport_ID='3692', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Ralph Wien Memorial Airport', Airport_ID='3693', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Edward G. Pitka Sr Airport', Airport_ID='3764', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Ted Stevens Anchorage International Airport', Airport_ID='3774', state_name='Alaska'),
#  Row(_contains=True, Airport_name='King Salmon Airport', Airport_ID='3794', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Ketchikan International Airport', Airport_ID='3808', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Fairbanks International Airport', Airport_ID='3832', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Gulkana Airport', Airport_ID='3837', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Cold Bay Airport', Airport_ID='3854', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Sitka Rocky Gutierrez Airport', Airport_ID='3856', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Unalaska Airport', Airport_ID='3860', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Valdez Pioneer Field', Airport_ID='3865', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Ladd AAF Airfield', Airport_ID='3882', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Talkeetna Airport', Airport_ID='4004', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Petersburg James A Johnson Airport', Airport_ID='4147', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Gustavus Airport', Airport_ID='5960', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Skagway Airport', Airport_ID='5961', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Holy Cross Airport', Airport_ID='5962', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Haines Airport', Airport_ID='5963', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kalskag Airport', Airport_ID='5964', state_name='Alaska'),
#  Row(_contains=True, Airport_name='McGrath Airport', Airport_ID='5965', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Mountain Village Airport', Airport_ID='5966', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Aniak Airport', Airport_ID='5967', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Chevak Airport', Airport_ID='5968', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Wrangell Airport', Airport_ID='5969', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Aleknagik / New Airport', Airport_ID='6126', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Akutan Seaplane Base', Airport_ID='6134', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Anaktuvuk Pass Airport', Airport_ID='6712', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Anvik Airport', Airport_ID='6713', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Atqasuk Edward Burnell Sr Memorial Airport', Airport_ID='6714', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Hooper Bay Airport', Airport_ID='6716', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kaltag Airport', Airport_ID='6717', state_name='Alaska'),
#  Row(_contains=True, Airport_name="St Mary's Airport", Airport_ID='6718', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kivalina Airport', Airport_ID='6719', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Mekoryuk Airport', Airport_ID='6720', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Ruby Airport', Airport_ID='6722', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Shishmaref Airport', Airport_ID='6723', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Noatak Airport', Airport_ID='6725', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Arctic Village Airport', Airport_ID='6729', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Port Clarence Coast Guard Station', Airport_ID='6736', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Sand Point Airport', Airport_ID='6742', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Deering Airport', Airport_ID='6755', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Igiugig Airport', Airport_ID='6763', state_name='Alaska'),
#  Row(_contains=True, Airport_name='New Stuyahok Airport', Airport_ID='6764', state_name='Alaska'),
#  Row(_contains=True, Airport_name='King Cove Airport', Airport_ID='6765', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Port Heiden Airport', Airport_ID='6766', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Togiak Airport', Airport_ID='6767', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Yakutat Airport', Airport_ID='6803', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Allakaket Airport', Airport_ID='6839', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Seward Airport', Airport_ID='6845', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Chefornak Airport', Airport_ID='6960', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Emmonak Airport', Airport_ID='7087', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Unalakleet Airport', Airport_ID='7088', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Ugnu-Kuparuk Airport', Airport_ID='7089', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Shageluk Airport', Airport_ID='7090', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Chuathbaluk Airport', Airport_ID='7091', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nuiqsut Airport', Airport_ID='7092', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Eek Airport', Airport_ID='7093', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kasigluk Airport', Airport_ID='7094', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kwethluk Airport', Airport_ID='7095', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kwigillingok Airport', Airport_ID='7096', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Marshall Don Hunter Sr Airport', Airport_ID='7097', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Russian Mission Airport', Airport_ID='7098', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Koliganek Airport', Airport_ID='7101', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Manokotak Airport', Airport_ID='7103', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Chalkyitsik Airport', Airport_ID='7105', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Eagle Airport', Airport_ID='7106', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Hughes Airport', Airport_ID='7107', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Huslia Airport', Airport_ID='7108', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nulato Airport', Airport_ID='7111', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Venetie Airport', Airport_ID='7114', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Beaver Airport', Airport_ID='7115', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Central Airport', Airport_ID='7116', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Shungnak Airport', Airport_ID='7117', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Angoon Seaplane Base', Airport_ID='7135', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Elfin Cove Seaplane Base', Airport_ID='7136', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Funter Bay Seaplane Base', Airport_ID='7140', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Hoonah Airport', Airport_ID='7142', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kake Airport', Airport_ID='7143', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Metlakatla Seaplane Base', Airport_ID='7146', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Hydaburg Seaplane Base', Airport_ID='7148', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Egegik Airport', Airport_ID='7154', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Perryville Airport', Airport_ID='7157', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Pilot Point Airport', Airport_ID='7158', state_name='Alaska'),
#  Row(_contains=True, Airport_name='South Naknek Nr 2 Airport', Airport_ID='7159', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Akhiok Airport', Airport_ID='7160', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Karluk Airport', Airport_ID='7161', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Larsen Bay Airport', Airport_ID='7162', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Ambler Airport', Airport_ID='7177', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Buckland Airport', Airport_ID='7178', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Bob Baker Memorial Airport', Airport_ID='7179', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kobuk Airport', Airport_ID='7180', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Robert (Bob) Curtis Memorial Airport', Airport_ID='7181', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Selawik Airport', Airport_ID='7182', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Brevig Mission Airport', Airport_ID='7183', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Elim Airport', Airport_ID='7184', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Golovin Airport', Airport_ID='7185', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Teller Airport', Airport_ID='7186', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Wales Airport', Airport_ID='7187', state_name='Alaska'),
#  Row(_contains=True, Airport_name='White Mountain Airport', Airport_ID='7188', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Koyuk Alfred Adams Airport', Airport_ID='7190', state_name='Alaska'),
#  Row(_contains=True, Airport_name='St Michael Airport', Airport_ID='7191', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Shaktoolik Airport', Airport_ID='7192', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Tin City Long Range Radar Station Airport', Airport_ID='7194', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nikolski Air Station', Airport_ID='7196', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Yakataga Airport', Airport_ID='7198', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Alakanuk Airport', Airport_ID='7199', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kipnuk Airport', Airport_ID='7201', state_name='Alaska'),
#  Row(_contains=True, Airport_name='False Pass Airport', Airport_ID='7202', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nelson Lagoon Airport', Airport_ID='7203', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Port Moller Airport', Airport_ID='7204', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Klawock Airport', Airport_ID='7205', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Quinhagak Airport', Airport_ID='7206', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kotlik Airport', Airport_ID='7207', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Koyukuk Airport', Airport_ID='7208', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Scammon Bay Airport', Airport_ID='7209', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nondalton Airport', Airport_ID='7210', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Kongiganak Airport', Airport_ID='7213', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nikolai Airport', Airport_ID='7214', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Akiak Airport', Airport_ID='7217', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Wainwright Airport', Airport_ID='7220', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Chenega Bay Airport', Airport_ID='7233', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Tok Junction Airport', Airport_ID='7235', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Circle City /New/ Airport', Airport_ID='7236', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Sleetmute Airport', Airport_ID='7240', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Healy River Airport', Airport_ID='7242', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Klawock Seaplane Base', Airport_ID='7244', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Minchumina Airport', Airport_ID='7245', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Manley Hot Springs Airport', Airport_ID='7246', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Whittier Airport', Airport_ID='7691', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Soldotna Airport', Airport_ID='7692', state_name='Alaska'),
#  Row(_contains=True, Airport_name='McKinley National Park Airport', Airport_ID='8050', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Lake Hood Airport', Airport_ID='8051', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Prospect Creek Airport', Airport_ID='8052', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nightmute Airport', Airport_ID='8199', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Toksook Bay Airport', Airport_ID='8200', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Birchwood Airport', Airport_ID='8227', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Port Alsworth Airport', Airport_ID='9387', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Napakiak Airport', Airport_ID='9739', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Napaskiak Airport', Airport_ID='9744', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Tok Airport', Airport_ID='9746', state_name='Alaska'),
#  Row(_contains=True, Airport_name='King Ranch Airport', Airport_ID='11079', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Nenana Municipal Airport', Airport_ID='11918', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Wasilla Airport', Airport_ID='11919', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Clarks Point Airport', Airport_ID='13336', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Red Dog Airport', Airport_ID='13439', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Denali Airport', Airport_ID='13635', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Seldovia Airport', Airport_ID='13707', state_name='Alaska'),
#  Row(_contains=True, Airport_name='Ernest A. Love Field', Airport_ID='3446', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Phoenix Sky Harbor International Airport', Airport_ID='3462', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Bisbee Douglas International Airport', Airport_ID='3474', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Luke Air Force Base', Airport_ID='3506', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Davis Monthan Air Force Base', Airport_ID='3562', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Yuma MCAS/Yuma International Airport', Airport_ID='3596', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Sierra Vista Municipal Libby Army Air Field', Airport_ID='3601', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Tucson International Airport', Airport_ID='3636', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Chandler Municipal Airport', Airport_ID='3765', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Nogales International Airport', Airport_ID='3788', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Page Municipal Airport', Airport_ID='4124', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Grand Canyon National Park Airport', Airport_ID='4219', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Flagstaff Pulliam Airport', Airport_ID='4261', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Sedona Airport', Airport_ID='4280', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Phoenix-Mesa-Gateway Airport', Airport_ID='6505', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Show Low Regional Airport', Airport_ID='7078', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Phoenix Goodyear Airport', Airport_ID='7126', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Lake Havasu City Airport', Airport_ID='7586', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Winslow Lindbergh Regional Airport', Airport_ID='7587', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Douglas Municipal Airport', Airport_ID='7588', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Scottsdale Airport', Airport_ID='7649', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Marana Regional Airport', Airport_ID='7979', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Casa Grande Municipal Airport', Airport_ID='7980', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Mobile Airport', Airport_ID='7981', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Buckeye Municipal Airport', Airport_ID='7982', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Gila Bend Municipal Airport', Airport_ID='7983', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Phoenix Deer Valley Airport', Airport_ID='8030', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Sky Ranch At Carefree Airport', Airport_ID='8397', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Falcon Field', Airport_ID='8869', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Coolidge Municipal Airport', Airport_ID='8870', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Cottonwood Airport', Airport_ID='8871', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Ak-Chin Regional Airport', Airport_ID='8874', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Wickenburg Municipal Airport', Airport_ID='8875', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Pinal Airpark', Airport_ID='9138', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Glendale Municipal Airport', Airport_ID='9139', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Safford Regional Airport', Airport_ID='9140', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Ryan Field', Airport_ID='11017', state_name='Arizona'),
#  Row(_contains=True, Airport_name='Fort Smith Regional Airport', Airport_ID='3437', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Pine Bluff Regional Airport, Grider Field', Airport_ID='3443', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Boone County Airport', Airport_ID='3461', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Little Rock Air Force Base', Airport_ID='3479', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Robinson Army Air Field', Airport_ID='3501', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Arkansas International Airport', Airport_ID='3523', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Jonesboro Municipal Airport', Airport_ID='3591', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Bill & Hillary Clinton National Airport/Adams Field', Airport_ID='3660', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='South Arkansas Regional At Goodwin Field', Airport_ID='3696', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Drake Field', Airport_ID='3760', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Texarkana Regional Webb Field', Airport_ID='3770', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Northwest Arkansas Regional Airport', Airport_ID='4356', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Memorial Field', Airport_ID='5741', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Ozark Regional Airport', Airport_ID='11821', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Monticello Municipal Ellis Field', Airport_ID='11838', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Saline County Regional Airport', Airport_ID='11857', state_name='Arkansas'),
#  Row(_contains=True, Airport_name="Schroeder's field", Airport_ID='11933', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Bentonville Municipal-Louise M Thaden Field', Airport_ID='13135', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Marion County Regional Airport', Airport_ID='13156', state_name='Arkansas'),
#  Row(_contains=True, Airport_name='Marina Municipal Airport', Airport_ID='3433', state_name='California'),
#  Row(_contains=True, Airport_name='Sacramento Mather Airport', Airport_ID='3434', state_name='California'),
#  Row(_contains=True, Airport_name='Bicycle Lake Army Air Field', Airport_ID='3435', state_name='California'),
#  Row(_contains=True, Airport_name='Twentynine Palms (Self) Airport', Airport_ID='3436', state_name='California'),
#  Row(_contains=True, Airport_name='Travis Air Force Base', Airport_ID='3449', state_name='California'),
#  Row(_contains=True, Airport_name='Metropolitan Oakland International Airport', Airport_ID='3453', state_name='California'),
#  Row(_contains=True, Airport_name='San Francisco International Airport', Airport_ID='3469', state_name='California'),
#  Row(_contains=True, Airport_name='Los Angeles International Airport', Airport_ID='3484', state_name='California'),
#  Row(_contains=True, Airport_name='China Lake Naws (Armitage Field) Airport', Airport_ID='3490', state_name='California'),
#  Row(_contains=True, Airport_name='Miramar Marine Corps Air Station - Mitscher Field', Airport_ID='3505', state_name='California'),
#  Row(_contains=True, Airport_name='Jack Northrop Field Hawthorne Municipal Airport', Airport_ID='3508', state_name='California'),
#  Row(_contains=True, Airport_name='Point Mugu Naval Air Station (Naval Base Ventura Co)', Airport_ID='3511', state_name='California'),
#  Row(_contains=True, Airport_name='Edwards Air Force Base', Airport_ID='3512', state_name='California'),
#  Row(_contains=True, Airport_name='Lemoore Naval Air Station (Reeves Field) Airport', Airport_ID='3516', state_name='California'),
#  Row(_contains=True, Airport_name='Southern California Logistics Airport', Airport_ID='3554', state_name='California'),
#  Row(_contains=True, Airport_name='Meadows Field', Airport_ID='3558', state_name='California'),
#  Row(_contains=True, Airport_name='Long Beach /Daugherty Field/ Airport', Airport_ID='3582', state_name='California'),
#  Row(_contains=True, Airport_name='North Island Naval Air Station-Halsey Field', Airport_ID='3594', state_name='California'),
#  Row(_contains=True, Airport_name='Beale Air Force Base', Airport_ID='3638', state_name='California'),
#  Row(_contains=True, Airport_name='Rancho Murieta Airport', Airport_ID='3643', state_name='California'),
#  Row(_contains=True, Airport_name='Bob Hope Airport', Airport_ID='3644', state_name='California'),
#  Row(_contains=True, Airport_name='Sacramento Executive Airport', Airport_ID='3663', state_name='California'),
#  Row(_contains=True, Airport_name='Castle Airport', Airport_ID='3683', state_name='California'),
#  Row(_contains=True, Airport_name='Mc Clellan Airfield', Airport_ID='3684', state_name='California'),
#  Row(_contains=True, Airport_name='Fresno Yosemite International Airport', Airport_ID='3687', state_name='California'),
#  Row(_contains=True, Airport_name='Imperial County Airport', Airport_ID='3689', state_name='California'),
#  Row(_contains=True, Airport_name='Calexico International Airport', Airport_ID='3709', state_name='California'),
#  Row(_contains=True, Airport_name='Chico Municipal Airport', Airport_ID='3710', state_name='California'),
#  Row(_contains=True, Airport_name='San Diego International Airport', Airport_ID='3731', state_name='California'),
#  Row(_contains=True, Airport_name='Ontario International Airport', Airport_ID='3734', state_name='California'),
#  Row(_contains=True, Airport_name='Norman Y. Mineta San Jose International Airport', Airport_ID='3748', state_name='California'),
#  Row(_contains=True, Airport_name='Palmdale Regional/USAF Plant 42 Airport', Airport_ID='3756', state_name='California'),
#  Row(_contains=True, Airport_name='El Centro NAF Airport (Vraciu Field)', Airport_ID='3758', state_name='California'),
#  Row(_contains=True, Airport_name='Moffett Federal Airfield', Airport_ID='3783', state_name='California'),
#  Row(_contains=True, Airport_name='Riverside Municipal Airport', Airport_ID='3799', state_name='California'),
#  Row(_contains=True, Airport_name='Stockton Metropolitan Airport', Airport_ID='3805', state_name='California'),
#  Row(_contains=True, Airport_name='Vandenberg Air Force Base', Airport_ID='3810', state_name='California'),
#  Row(_contains=True, Airport_name='March ARB Airport', Airport_ID='3815', state_name='California'),
#  Row(_contains=True, Airport_name='Modesto City Co-Harry Sham Field', Airport_ID='3816', state_name='California'),
#  Row(_contains=True, Airport_name='Sacramento International Airport', Airport_ID='3817', state_name='California'),
#  Row(_contains=True, Airport_name='Palm Springs International Airport', Airport_ID='3839', state_name='California'),
#  Row(_contains=True, Airport_name='John Wayne Airport-Orange County Airport', Airport_ID='3867', state_name='California'),
#  Row(_contains=True, Airport_name='Monterey Peninsula Airport', Airport_ID='3948', state_name='California'),
#  Row(_contains=True, Airport_name='Santa Barbara Municipal Airport', Airport_ID='3949', state_name='California'),
#  Row(_contains=True, Airport_name='Van Nuys Airport', Airport_ID='4071', state_name='California'),
#  Row(_contains=True, Airport_name='Mc Clellan-Palomar Airport', Airport_ID='4088', state_name='California'),
#  Row(_contains=True, Airport_name='Redding Municipal Airport', Airport_ID='4098', state_name='California'),
#  Row(_contains=True, Airport_name='Blythe Airport', Airport_ID='4136', state_name='California'),
#  Row(_contains=True, Airport_name='Lake Tahoe Airport', Airport_ID='4262', state_name='California'),
#  Row(_contains=True, Airport_name='El Toro Marine Corps Air Station', Airport_ID='4298', state_name='California'),
#  Row(_contains=True, Airport_name='California Redwood Coast-Humboldt County Airport', Airport_ID='4384', state_name='California'),
#  Row(_contains=True, Airport_name='Los Alamitos Army Air Field', Airport_ID='5613', state_name='California'),
#  Row(_contains=True, Airport_name='Jack Mc Namara Field Airport', Airport_ID='5727', state_name='California'),
#  Row(_contains=True, Airport_name='San Luis County Regional Airport', Airport_ID='5768', state_name='California'),
#  Row(_contains=True, Airport_name='Santa Maria Pub/Capt G Allan Hancock Field', Airport_ID='5772', state_name='California'),
#  Row(_contains=True, Airport_name='Fullerton Municipal Airport', Airport_ID='6481', state_name='California'),
#  Row(_contains=True, Airport_name='Oceanside Municipal Airport', Airport_ID='6829', state_name='California'),
#  Row(_contains=True, Airport_name='Oxnard Airport', Airport_ID='6961', state_name='California'),
#  Row(_contains=True, Airport_name='Charles M. Schulz Sonoma County Airport', Airport_ID='6992', state_name='California'),
#  Row(_contains=True, Airport_name='Mojave Airport', Airport_ID='7026', state_name='California'),
#  Row(_contains=True, Airport_name='Zamperini Field', Airport_ID='7053', state_name='California'),
#  Row(_contains=True, Airport_name='Mammoth Yosemite Airport', Airport_ID='7081', state_name='California'),
#  Row(_contains=True, Airport_name='Inyokern Airport', Airport_ID='7120', state_name='California'),
#  Row(_contains=True, Airport_name='Visalia Municipal Airport', Airport_ID='7121', state_name='California'),
#  Row(_contains=True, Airport_name='Merced Regional Macready Field', Airport_ID='7122', state_name='California'),
#  Row(_contains=True, Airport_name='Livermore Municipal Airport', Airport_ID='7629', state_name='California'),
#  Row(_contains=True, Airport_name='Mariposa Yosemite Airport', Airport_ID='7630', state_name='California'),
#  Row(_contains=True, Airport_name='Jacqueline Cochran Regional Airport', Airport_ID='7646', state_name='California'),
#  Row(_contains=True, Airport_name='Santa Monica Municipal Airport', Airport_ID='7647', state_name='California'),
#  Row(_contains=True, Airport_name='Bermuda Dunes Airport', Airport_ID='7648', state_name='California'),
#  Row(_contains=True, Airport_name='Yolo County Davis Woodland Winters Airport', Airport_ID='7651', state_name='California'),
#  Row(_contains=True, Airport_name='Napa County Airport', Airport_ID='7658', state_name='California'),
#  Row(_contains=True, Airport_name='Brown Field Municipal Airport', Airport_ID='7659', state_name='California'),
#  Row(_contains=True, Airport_name='San Bernardino International Airport', Airport_ID='7670', state_name='California'),
#  Row(_contains=True, Airport_name='San Carlos Airport', Airport_ID='7683', state_name='California'),
#  Row(_contains=True, Airport_name='Gillespie Field', Airport_ID='7693', state_name='California'),
#  Row(_contains=True, Airport_name='Truckee Tahoe Airport', Airport_ID='7702', state_name='California'),
#  Row(_contains=True, Airport_name='French Valley Airport', Airport_ID='7769', state_name='California'),
#  Row(_contains=True, Airport_name='Yuba County Airport', Airport_ID='7875', state_name='California'),
#  Row(_contains=True, Airport_name='Buchanan Field', Airport_ID='7888', state_name='California'),
#  Row(_contains=True, Airport_name='Red Bluff Municipal Airport', Airport_ID='8137', state_name='California'),
#  Row(_contains=True, Airport_name='Marin County Airport - Gnoss Field', Airport_ID='8138', state_name='California'),
#  Row(_contains=True, Airport_name='Whiteman Airport', Airport_ID='8220', state_name='California'),
#  Row(_contains=True, Airport_name='Madera Municipal Airport', Airport_ID='8221', state_name='California'),
#  Row(_contains=True, Airport_name='Redlands Municipal Airport', Airport_ID='8443', state_name='California'),
#  Row(_contains=True, Airport_name='Flabob Airport', Airport_ID='8445', state_name='California'),
#  Row(_contains=True, Airport_name='Ramona Airport', Airport_ID='8608', state_name='California'),
#  Row(_contains=True, Airport_name='Lompoc Airport', Airport_ID='8771', state_name='California'),
#  Row(_contains=True, Airport_name='Brackett Field', Airport_ID='8798', state_name='California'),
#  Row(_contains=True, Airport_name='Palo Alto Airport of Santa Clara County', Airport_ID='8864', state_name='California'),
#  Row(_contains=True, Airport_name='Hayward Executive Airport', Airport_ID='8982', state_name='California'),
#  Row(_contains=True, Airport_name='Alameda Naval Air Station', Airport_ID='9071', state_name='California'),
#  Row(_contains=True, Airport_name='Rancho San Simeon Airport', Airport_ID='9104', state_name='California'),
#  Row(_contains=True, Airport_name='Lincoln Regional Karl Harder Field', Airport_ID='9184', state_name='California'),
#  Row(_contains=True, Airport_name='San Gabriel Valley Airport', Airport_ID='10017', state_name='California'),
#  Row(_contains=True, Airport_name='Cable Airport', Airport_ID='10117', state_name='California'),
#  Row(_contains=True, Airport_name='Chino Airport', Airport_ID='10162', state_name='California'),
#  Row(_contains=True, Airport_name='Paso Robles Municipal Airport', Airport_ID='10185', state_name='California'),
#  Row(_contains=True, Airport_name='Half Moon Bay Airport', Airport_ID='10360', state_name='California'),
#  Row(_contains=True, Airport_name='General WM J Fox Airfield', Airport_ID='10371', state_name='California'),
#  Row(_contains=True, Airport_name='Banning Municipal Airport', Airport_ID='11131', state_name='California'),
#  Row(_contains=True, Airport_name='Reid-Hillview Airport of Santa Clara County', Airport_ID='11312', state_name='California'),
#  Row(_contains=True, Airport_name='Camarillo Airport', Airport_ID='11438', state_name='California'),
#  Row(_contains=True, Airport_name='Watsonville Municipal Airport', Airport_ID='11638', state_name='California'),
#  Row(_contains=True, Airport_name='Hollister Municipal Airport', Airport_ID='11648', state_name='California'),
#  Row(_contains=True, Airport_name='Eastern Sierra Regional Airport', Airport_ID='11818', state_name='California'),
#  Row(_contains=True, Airport_name='Barstow Daggett Airport', Airport_ID='11829', state_name='California'),
#  Row(_contains=True, Airport_name='Needles Airport', Airport_ID='11832', state_name='California'),
#  Row(_contains=True, Airport_name='Murray Field', Airport_ID='11834', state_name='California'),
#  Row(_contains=True, Airport_name='Salinas Municipal Airport', Airport_ID='11855', state_name='California'),
#  Row(_contains=True, Airport_name='Ukiah Municipal Airport', Airport_ID='11860', state_name='California'),
#  Row(_contains=True, Airport_name='Tracy Municipal Airport', Airport_ID='12185', state_name='California'),
#  Row(_contains=True, Airport_name='Santa Ynez Airport', Airport_ID='13189', state_name='California'),
#  Row(_contains=True, Airport_name='Camp Pendleton MCAS (Munn Field) Airport', Airport_ID='13717', state_name='California'),
#  Row(_contains=True, Airport_name='Butts AAF (Fort Carson) Air Field', Airport_ID='3503', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Pueblo Memorial Airport', Airport_ID='3527', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Buckley Air Force Base', Airport_ID='3567', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Durango La Plata County Airport', Airport_ID='3713', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Denver International Airport', Airport_ID='3751', state_name='Colorado'),
#  Row(_contains=True, Airport_name='City of Colorado Springs Municipal Airport', Airport_ID='3819', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Grand Junction Regional Airport', Airport_ID='4063', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Telluride Regional Airport', Airport_ID='4084', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Centennial Airport', Airport_ID='4222', state_name='Colorado'),
#  Row(_contains=True, Airport_name='La Junta Municipal Airport', Airport_ID='4227', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Eagle County Regional Airport', Airport_ID='4250', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Northern Colorado Regional Airport', Airport_ID='4257', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Cortez Municipal Airport', Airport_ID='4338', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Yampa Valley Airport', Airport_ID='4339', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Lamar Municipal Airport', Airport_ID='4342', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Montrose Regional Airport', Airport_ID='6880', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Aspen-Pitkin Co/Sardy Field', Airport_ID='7001', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Gunnison Crested Butte Regional Airport', Airport_ID='7051', state_name='Colorado'),
#  Row(_contains=True, Airport_name='San Luis Valley Regional Bergman Field', Airport_ID='7073', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Steamboat Springs Bob Adams Field', Airport_ID='7580', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Garfield County Regional Airport', Airport_ID='7652', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Rocky Mountain Metropolitan Airport', Airport_ID='7822', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Sterling Municipal Airport', Airport_ID='7985', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Boulder Municipal Airport', Airport_ID='8854', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Colorado Springs East Airport', Airport_ID='9429', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Colorado Plains Regional Airport', Airport_ID='9546', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Front Range Airport', Airport_ID='11081', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Flagler Aerial Spraying Inc Airport', Airport_ID='11089', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Greeley–Weld County Airport', Airport_ID='11098', state_name='Colorado'),
#  Row(_contains=True, Airport_name='Igor I Sikorsky Memorial Airport', Airport_ID='3579', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Hartford Brainard Airport', Airport_ID='3780', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Bradley International Airport', Airport_ID='3825', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Tweed New Haven Airport', Airport_ID='4006', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Groton New London Airport', Airport_ID='4270', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Windham Airport', Airport_ID='8282', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Danbury Municipal Airport', Airport_ID='8286', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Waterbury Oxford Airport', Airport_ID='8289', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Meriden Markham Municipal Airport', Airport_ID='11035', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Danielson Airport', Airport_ID='12796', state_name='Connecticut'),
#  Row(_contains=True, Airport_name='Dover Air Force Base', Airport_ID='3487', state_name='Delaware'),
#  Row(_contains=True, Airport_name='New Castle Airport', Airport_ID='3859', state_name='Delaware'),
#  Row(_contains=True, Airport_name='Sussex County Airport', Airport_ID='7011', state_name='Delaware'),
#  Row(_contains=True, Airport_name='Orlando Executive Airport', Airport_ID='3416', state_name='Florida'),
#  Row(_contains=True, Airport_name='Whiting Field Naval Air Station - North', Airport_ID='3444', state_name='Florida'),
#  Row(_contains=True, Airport_name='Fort Lauderdale Executive Airport', Airport_ID='3464', state_name='Florida'),
#  Row(_contains=True, Airport_name='North Perry Airport', Airport_ID='3468', state_name='Florida'),
#  Row(_contains=True, Airport_name='Gainesville Regional Airport', Airport_ID='3472', state_name='Florida'),
#  Row(_contains=True, Airport_name='Hurlburt Field', Airport_ID='3507', state_name='Florida'),
#  Row(_contains=True, Airport_name='Fort Lauderdale Hollywood International Airport', Airport_ID='3533', state_name='Florida'),
#  Row(_contains=True, Airport_name='Albert Whitted Airport', Airport_ID='3548', state_name='Florida'),
#  Row(_contains=True, Airport_name='Page Field', Airport_ID='3549', state_name='Florida'),
#  Row(_contains=True, Airport_name='Bob Sikes Airport', Airport_ID='3555', state_name='Florida'),
#  Row(_contains=True, Airport_name='Pensacola Naval Air Station/Forrest Sherman Field', Airport_ID='3563', state_name='Florida'),
#  Row(_contains=True, Airport_name='Pensacola Regional Airport', Airport_ID='3564', state_name='Florida'),
#  Row(_contains=True, Airport_name='Miami International Airport', Airport_ID='3576', state_name='Florida'),
#  Row(_contains=True, Airport_name='Palm Beach County Park Airport', Airport_ID='3593', state_name='Florida'),
#  Row(_contains=True, Airport_name='St Petersburg Clearwater International Airport', Airport_ID='3617', state_name='Florida'),
#  Row(_contains=True, Airport_name='Patrick Air Force Base', Airport_ID='3623', state_name='Florida'),
#  Row(_contains=True, Airport_name='Tampa International Airport', Airport_ID='3646', state_name='Florida'),
#  Row(_contains=True, Airport_name='Tyndall Air Force Base', Airport_ID='3669', state_name='Florida'),
#  Row(_contains=True, Airport_name='Melbourne International Airport', Airport_ID='3671', state_name='Florida'),
#  Row(_contains=True, Airport_name='Vero Beach Regional Airport', Airport_ID='3688', state_name='Florida'),
#  Row(_contains=True, Airport_name='Tallahassee Regional Airport', Airport_ID='3698', state_name='Florida'),
#  Row(_contains=True, Airport_name='Jacksonville Naval Air Station (Towers Field)', Airport_ID='3703', state_name='Florida'),
#  Row(_contains=True, Airport_name='Jacksonville International Airport', Airport_ID='3712', state_name='Florida'),
#  Row(_contains=True, Airport_name='Dade Collier Training and Transition Airport', Airport_ID='3721', state_name='Florida'),
#  Row(_contains=True, Airport_name='Palm Beach International Airport', Airport_ID='3722', state_name='Florida'),
#  Row(_contains=True, Airport_name='Naval Air Station Key West/Boca Chica Field', Airport_ID='3746', state_name='Florida'),
#  Row(_contains=True, Airport_name='Mac Dill Air Force Base', Airport_ID='3789', state_name='Florida'),
#  Row(_contains=True, Airport_name='Opa-locka Executive Airport', Airport_ID='3791', state_name='Florida'),
#  Row(_contains=True, Airport_name='Southwest Florida International Airport', Airport_ID='3793', state_name='Florida'),
#  Row(_contains=True, Airport_name='Homestead ARB Airport', Airport_ID='3798', state_name='Florida'),
#  Row(_contains=True, Airport_name='Boca Raton Airport', Airport_ID='3831', state_name='Florida'),
#  Row(_contains=True, Airport_name='Kendall-Tamiami Executive Airport', Airport_ID='3869', state_name='Florida'),
#  Row(_contains=True, Airport_name='Destin-Ft Walton Beach Airport', Airport_ID='3873', state_name='Florida'),
#  Row(_contains=True, Airport_name='Key West International Airport', Airport_ID='3875', state_name='Florida'),
#  Row(_contains=True, Airport_name='Orlando International Airport', Airport_ID='3878', state_name='Florida'),
#  Row(_contains=True, Airport_name='Daytona Beach International Airport', Airport_ID='3950', state_name='Florida'),
# ...
#  Row(_contains=True, Airport_name='Indianola Municipal Airport', Airport_ID='7767', state_name='Mississippi'),
#  Row(_contains=True, Airport_name='Olive Branch Airport', Airport_ID='7817', state_name='Mississippi'),
#  Row(_contains=True, Airport_name='Tunica Municipal Airport', Airport_ID='7827', state_name='Mississippi'),
#  Row(_contains=True, Airport_name='Hattiesburg Bobby L Chain Municipal Airport', Airport_ID='8951', state_name='Mississippi'),
#  Row(_contains=True, Airport_name='Clarke County Airport', Airport_ID='9448', state_name='Mississippi'),
#  Row(_contains=True, Airport_name='Mc Comb/Pike County Airport/John E Lewis Field', Airport_ID='11841', state_name='Mississippi'),
#  Row(_contains=True, Airport_name='University Oxford Airport', Airport_ID='11861', state_name='Mississippi'),
#  Row(_contains=True, Airport_name='Stennis International Airport', Airport_ID='13694', state_name='Mississippi'),
#  Row(_contains=True, Airport_name='Kansas City International Airport', Airport_ID='3458', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Whiteman Air Force Base', Airport_ID='3586', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Waynesville-St. Robert Regional Forney field', Airport_ID='3665', state_name='Missouri'),
#  Row(_contains=True, Airport_name='St Louis Lambert International Airport', Airport_ID='3678', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Columbia Regional Airport', Airport_ID='3719', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Sherman Army Air Field', Airport_ID='3800', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Charles B. Wheeler Downtown Airport', Airport_ID='4293', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Springfield Branson National Airport', Airport_ID='4348', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Joplin Regional Airport', Airport_ID='4354', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Cape Girardeau Regional Airport', Airport_ID='5728', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Kirksville Regional Airport', Airport_ID='5744', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Jefferson City Memorial Airport', Airport_ID='6447', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Branson Airport', Airport_ID='6962', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Spirit of St Louis Airport', Airport_ID='7015', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Lee C Fine Memorial Airport', Airport_ID='7991', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Poplar Bluff Municipal Airport', Airport_ID='8664', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Sikeston Memorial Municipal Airport', Airport_ID='9164', state_name='Missouri'),
#  Row(_contains=True, Airport_name='El Dorado Springs Memorial Airport', Airport_ID='10105', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Turkey Mountain Estates Airport', Airport_ID='11087', state_name='Missouri'),
#  Row(_contains=True, Airport_name='Cut Bank International Airport', Airport_ID='3470', state_name='Montana'),
#  Row(_contains=True, Airport_name='Helena Regional Airport', Airport_ID='3504', state_name='Montana'),
#  Row(_contains=True, Airport_name='Havre City County Airport', Airport_ID='3604', state_name='Montana'),
#  Row(_contains=True, Airport_name='Great Falls International Airport', Airport_ID='3880', state_name='Montana'),
#  Row(_contains=True, Airport_name='Gallatin Field', Airport_ID='4020', state_name='Montana'),
#  Row(_contains=True, Airport_name='Billings Logan International Airport', Airport_ID='4021', state_name='Montana'),
#  Row(_contains=True, Airport_name='Bert Mooney Airport', Airport_ID='4022', state_name='Montana'),
#  Row(_contains=True, Airport_name='Glacier Park International Airport', Airport_ID='4127', state_name='Montana'),
#  Row(_contains=True, Airport_name='Missoula International Airport', Airport_ID='4216', state_name='Montana'),
#  Row(_contains=True, Airport_name='Wokal Field Glasgow International Airport', Airport_ID='5739', state_name='Montana'),
#  Row(_contains=True, Airport_name='Lewistown Municipal Airport', Airport_ID='5752', state_name='Montana'),
#  Row(_contains=True, Airport_name='Frank Wiley Field', Airport_ID='5755', state_name='Montana'),
#  Row(_contains=True, Airport_name='Sidney - Richland Regional Airport', Airport_ID='7065', state_name='Montana'),
#  Row(_contains=True, Airport_name='Dawson Community Airport', Airport_ID='7070', state_name='Montana'),
#  Row(_contains=True, Airport_name='L M Clayton Airport', Airport_ID='7071', state_name='Montana'),
#  Row(_contains=True, Airport_name='Yellowstone Airport', Airport_ID='7072', state_name='Montana'),
#  Row(_contains=True, Airport_name='Dell Flight Strip', Airport_ID='7716', state_name='Montana'),
#  Row(_contains=True, Airport_name='Mission Field', Airport_ID='7717', state_name='Montana'),
#  Row(_contains=True, Airport_name='Big Timber Airport', Airport_ID='7720', state_name='Montana'),
#  Row(_contains=True, Airport_name='Glasgow Industrial Airport', Airport_ID='8893', state_name='Montana'),
#  Row(_contains=True, Airport_name='Eppley Airfield', Airport_ID='3454', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Lincoln Airport', Airport_ID='3543', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Offutt Air Force Base', Airport_ID='3836', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Western Neb. Rgnl/William B. Heilig Airport', Airport_ID='5723', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Central Nebraska Regional Airport', Airport_ID='5740', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='North Platte Regional Airport Lee Bird Field', Airport_ID='5748', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Chadron Municipal Airport', Airport_ID='7066', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Alliance Municipal Airport', Airport_ID='7067', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Mc Cook Ben Nelson Regional Airport', Airport_ID='7068', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Sidney Municipal-Lloyd W Carr Field', Airport_ID='8815', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Brewster Field', Airport_ID='11070', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Wahoo Municipal Airport', Airport_ID='11073', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Jim Kelly Field', Airport_ID='11074', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Fremont Municipal Airport', Airport_ID='11101', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Karl Stefan Memorial Airport', Airport_ID='11134', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Columbus Municipal Airport', Airport_ID='11847', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Miller Field', Airport_ID='11863', state_name='Nebraska'),
#  Row(_contains=True, Airport_name='Creech Air Force Base', Airport_ID='3496', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Tonopah Test Range Airport', Airport_ID='3592', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Fallon Naval Air Station', Airport_ID='3741', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Reno Tahoe International Airport', Airport_ID='3807', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Nellis Air Force Base', Airport_ID='3814', state_name='Nevada'),
#  Row(_contains=True, Airport_name='McCarran International Airport', Airport_ID='3877', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Elko Regional Airport', Airport_ID='5736', state_name='Nevada'),
#  Row(_contains=True, Airport_name='North Las Vegas Airport', Airport_ID='6877', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Ely Airport Yelland Field', Airport_ID='7075', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Henderson Executive Airport', Airport_ID='7999', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Silver Springs Airport', Airport_ID='8219', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Desert Rock Airport', Airport_ID='11831', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Derby Field', Airport_ID='11839', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Tonopah Airport', Airport_ID='11858', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Winnemucca Municipal Airport', Airport_ID='11864', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Homey (Area 51) Airport', Airport_ID='11867', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Las Vegas Helicopters Heliport', Airport_ID='13018', state_name='Nevada'),
#  Row(_contains=True, Airport_name='Manchester-Boston Regional Airport', Airport_ID='4011', state_name='New Hampshire'),
#  Row(_contains=True, Airport_name='Concord Municipal Airport', Airport_ID='4268', state_name='New Hampshire'),
#  Row(_contains=True, Airport_name='Lebanon Municipal Airport', Airport_ID='5749', state_name='New Hampshire'),
#  Row(_contains=True, Airport_name='Portsmouth International at Pease Airport', Airport_ID='5763', state_name='New Hampshire'),
#  Row(_contains=True, Airport_name='Boire Field', Airport_ID='8287', state_name='New Hampshire'),
#  Row(_contains=True, Airport_name='Dillant Hopkins Airport', Airport_ID='8888', state_name='New Hampshire'),
#  Row(_contains=True, Airport_name='Skyhaven Airport', Airport_ID='9396', state_name='New Hampshire'),
#  Row(_contains=True, Airport_name='Trenton Mercer Airport', Airport_ID='3447', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Newark Liberty International Airport', Airport_ID='3494', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Atlantic City International Airport', Airport_ID='3524', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Teterboro Airport', Airport_ID='3624', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Mc Guire Air Force Base', Airport_ID='3655', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Millville Municipal Airport', Airport_ID='3679', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Cape May County Airport', Airport_ID='3740', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Lakehurst Maxfield Field Airport', Airport_ID='3812', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Morristown Municipal Airport', Airport_ID='7657', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Essex County Airport', Airport_ID='7990', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='South Jersey Regional Airport', Airport_ID='8548', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Linden Airport', Airport_ID='8550', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Somerset Airport', Airport_ID='8665', state_name='New Jersey'),
#  Row(_contains=True, Airport_name='Grants-Milan Municipal Airport', Airport_ID='3439', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Cavern City Air Terminal', Airport_ID='3597', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Roswell International Air Center Airport', Airport_ID='3736', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Four Corners Regional Airport', Airport_ID='3743', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Lea County Regional Airport', Airport_ID='3749', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Truth Or Consequences Municipal Airport', Airport_ID='3755', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Tucumcari Municipal Airport', Airport_ID='3773', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Black Rock Airport', Airport_ID='3776', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Santa Fe Municipal Airport', Airport_ID='3784', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Holloman Air Force Base', Airport_ID='3802', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Cannon Air Force Base', Airport_ID='3834', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Condron Army Air Field', Airport_ID='3853', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Albuquerque International Sunport', Airport_ID='4019', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Clovis Municipal Airport', Airport_ID='4223', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Las Vegas Municipal Airport', Airport_ID='4225', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Las Cruces International Airport', Airport_ID='4228', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Gallup Municipal Airport', Airport_ID='4340', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Alamogordo White Sands Regional Airport', Airport_ID='5717', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Sierra Blanca Regional Airport', Airport_ID='7077', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Los Alamos Airport', Airport_ID='7584', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Deming Municipal Airport', Airport_ID='11830', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Double Eagle II Airport', Airport_ID='13130', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Socorro Municipal Airport', Airport_ID='13131', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Taos Regional Airport', Airport_ID='13139', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Raton Municipal-Crews Field', Airport_ID='13142', state_name='New Mexico'),
#  Row(_contains=True, Airport_name='Griffiss International Airport', Airport_ID='3450', state_name='New York'),
#  Row(_contains=True, Airport_name='Massena International Richards Field', Airport_ID='3546', state_name='New York'),
#  Row(_contains=True, Airport_name='Wheeler Sack Army Air Field', Airport_ID='3556', state_name='New York'),
#  Row(_contains=True, Airport_name='Westchester County Airport', Airport_ID='3589', state_name='New York'),
#  Row(_contains=True, Airport_name='Francis S Gabreski Airport', Airport_ID='3590', state_name='New York'),
#  Row(_contains=True, Airport_name='Greater Rochester International Airport', Airport_ID='3622', state_name='New York'),
#  Row(_contains=True, Airport_name='Niagara Falls International Airport', Airport_ID='3630', state_name='New York'),
#  Row(_contains=True, Airport_name='Stewart International Airport', Airport_ID='3661', state_name='New York'),
#  Row(_contains=True, Airport_name='La Guardia Airport', Airport_ID='3697', state_name='New York'),
#  Row(_contains=True, Airport_name='Ogdensburg International Airport', Airport_ID='3724', state_name='New York'),
#  Row(_contains=True, Airport_name='Syracuse Hancock International Airport', Airport_ID='3745', state_name='New York'),
#  Row(_contains=True, Airport_name='Plattsburgh International Airport', Airport_ID='3771', state_name='New York'),
#  Row(_contains=True, Airport_name='John F Kennedy International Airport', Airport_ID='3797', state_name='New York'),
#  Row(_contains=True, Airport_name='Buffalo Niagara International Airport', Airport_ID='3820', state_name='New York'),
#  Row(_contains=True, Airport_name='Watertown International Airport', Airport_ID='3838', state_name='New York'),
#  Row(_contains=True, Airport_name='Long Island Mac Arthur Airport', Airport_ID='3857', state_name='New York'),
#  Row(_contains=True, Airport_name='Albany International Airport', Airport_ID='3864', state_name='New York'),
#  Row(_contains=True, Airport_name='Elmira Corning Regional Airport', Airport_ID='3946', state_name='New York'),
#  Row(_contains=True, Airport_name='Ithaca Tompkins Regional Airport', Airport_ID='3947', state_name='New York'),
#  Row(_contains=True, Airport_name='Downtown-Manhattan/Wall St Heliport', Airport_ID='3993', state_name='New York'),
#  Row(_contains=True, Airport_name='Greater Binghamton/Edwin A Link field', Airport_ID='4129', state_name='New York'),
#  ...]
